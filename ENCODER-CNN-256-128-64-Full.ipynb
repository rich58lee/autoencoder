# %% [markdown]
# <h3>輸入原影像，經過壓縮轉換，再由轉換壓縮碼，還原成類原圖</h3>

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# %%
from glob import glob
import numpy

# %%
import cv2

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator

# %%
import keras
from keras import layers
from keras.models import Model
from keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from pylab import rcParams
from matplotlib import cm

# %% [markdown]
# <h3>環境設置</h3>

# %%
image_path = 'images/full'
max_dim = (256, 256, 3)
enhance_flag = False

kernel = numpy.array([[-1, -1, -1], [-1, 11, -1], [-1, -1, -1]])

alpha = 0.6 # Contrast control (1.0-3.0)
beta = 2 # Brightness control (0-100)

# %%
def read_image_file(my_image_file, enhanced=False):
    global max_dim, kernel, alpha, beta
    
    _fish_image = cv2.imread(my_image_file, cv2.COLOR_BGR2RGB)
    if _fish_image is None:
        print(my_image_file)
        return None
    
    if enhanced:
        _fish_image = cv2.filter2D(_fish_image, -1, kernel)
        _fish_image = cv2.convertScaleAbs(_fish_image.copy(), alpha=alpha, beta=beta)

    _fish_image = cv2.resize(_fish_image.copy(), max_dim[:2])
    
    return _fish_image

# %%
def show_image(my_image):
    global max_dim
    
    _my_image = numpy.reshape(my_image, max_dim)
    
    fig, ax = plt.subplots(dpi=120)
    
    ax.imshow(my_image)
    ax.axis('off')
    
    plt.show()

# %% [markdown]
# <h3>載入魚影像檔</h3>

# %%
datagen = ImageDataGenerator(rotation_range=45,
                             width_shift_range=[0.1, 0.2],
                             height_shift_range=[0.1, 0.2],
                             horizontal_flip=True)

_fish_image = read_image_file('%s/F000079.jpg' % image_path, enhance_flag)

fig, ax = plt.subplots(dpi=120, ncols=3)

ax[0].imshow(_fish_image)
ax[0].axis('off')

_fish_img_data = img_to_array(_fish_image)    
_fish_img_data = numpy.expand_dims(_fish_img_data, 0)

it = datagen.flow(_fish_img_data, batch_size=1)

for i in range(1, 3):
    _batch = it.next()
    _generated_image = _batch[0].astype('uint8')
            
    ax[i].imshow(_generated_image, cmap='gray', interpolation='bicubic')
    ax[i].axis('off')
    
plt.tight_layout()
plt.show()

# %%
def load_data(image_path, train_ratio=0.8, enhanced=False):
    global max_dim

    datagen = ImageDataGenerator(rotation_range=45,
                                 width_shift_range=[0.1, 0.2],
                                 height_shift_range=[0.1, 0.2],
                                 horizontal_flip=True
    )
    
    image_files = glob('%s/F*.jpg' % image_path)

    my_images = []

    for image_file in image_files:
        _image_file = image_file.replace('\\', '/')
        
        _fish_image = read_image_file(_image_file, enhanced)
        if _fish_image is None:
            print(_image_file)
            continue
        
        my_images.append(numpy.reshape(_fish_image, max_dim))

        _fish_img_data = img_to_array(_fish_image)    
        _fish_img_data = numpy.expand_dims(_fish_img_data, 0)
        
        it = datagen.flow(_fish_img_data, batch_size=1)

        for i in range(10):
            _batch = it.next()
            _generated_image = _batch[0].astype('uint8')
            
            my_images.append(numpy.reshape(_generated_image, max_dim))

    my_images = numpy.array(my_images)
    numpy.random.shuffle(my_images)
    
    pos = int(my_images.shape[0] * train_ratio)
    return my_images[:pos], my_images[pos:]

# %%
x_train, x_test = load_data(image_path, 0.8, enhance_flag)
# Out:
# images/full/F014360.jpg
# images/full/F014360.jpg

# %%
x_train.shape, x_test.shape
# Out:
# ((20204, 256, 256, 3), (5052, 256, 256, 3))

# %%
show_image(x_train[numpy.random.randint(len(x_train))])

# %% [markdown]
# <h3>將 0 ~ 255 值域，轉換為: 0 ~ 1</h3>

# %%
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# %% [markdown]
# <h3>參數設置</h3>
# <p>$$壓縮率: \frac {{256}*{256}={65536}}{64} = 1024$$</p>

# %% [markdown]
# <h3>建立模型</h3>

# %%
input_img = keras.Input(shape=max_dim, name='input')

# %%
x = layers.Conv2D(256, (3, 3), activation='relu', padding='same', name='Conv2D_256')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same', name='MaxPooling2D_256')(x)

# %%
x = layers.Conv2D(128, (3, 3), activation='relu', padding='same', name='Conv2D_128')(x)
x = layers.MaxPooling2D((2, 2), padding='same', name='MaxPooling2D_128')(x)

# %%
x = layers.Conv2D(64, (3, 3), activation='relu', padding='same', name='Conv2D_64')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same', name='latent')(x)

# %%
x = layers.Conv2DTranspose(64, (3, 3), activation='relu', padding='same', name='Conv2DT_64')(encoded)
x = layers.UpSampling2D((2, 2), name='UpSampling2D_64')(x)

# %%
x = layers.Conv2DTranspose(128, (3, 3), activation='relu', padding='same', name='Conv2DT_128')(x)
x = layers.UpSampling2D((2, 2), name='UpSampling2D_128')(x)

# %%
x = layers.Conv2DTranspose(256, (3, 3), activation='relu', padding='same', name='Conv2DT_256')(x)
x = layers.UpSampling2D((2, 2), name='UpSampling2D_256')(x)

# %%
decoded = layers.Conv2D(max_dim[-1], (3, 3), padding='same', name='output')(x)

# %%
autoencoder = keras.Model(input_img, decoded)

# %%
autoencoder.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 256, 256, 3)]     0
# _________________________________________________________________
# Conv2D_256 (Conv2D)          (None, 256, 256, 256)     7168
# _________________________________________________________________
# MaxPooling2D_256 (MaxPooling (None, 128, 128, 256)     0
# _________________________________________________________________
# Conv2D_128 (Conv2D)          (None, 128, 128, 128)     295040
# _________________________________________________________________
# MaxPooling2D_128 (MaxPooling (None, 64, 64, 128)       0
# _________________________________________________________________
# Conv2D_64 (Conv2D)           (None, 64, 64, 64)        73792
# _________________________________________________________________
# latent (MaxPooling2D)        (None, 32, 32, 64)        0
# _________________________________________________________________
# Conv2DT_64 (Conv2DTranspose) (None, 32, 32, 64)        36928
# _________________________________________________________________
# UpSampling2D_64 (UpSampling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# Conv2DT_128 (Conv2DTranspose (None, 64, 64, 128)       73856
# _________________________________________________________________
# UpSampling2D_128 (UpSampling (None, 128, 128, 128)     0
# _________________________________________________________________
# Conv2DT_256 (Conv2DTranspose (None, 128, 128, 256)     295168
# _________________________________________________________________
# UpSampling2D_256 (UpSampling (None, 256, 256, 256)     0
# _________________________________________________________________
# output (Conv2D)              (None, 256, 256, 3)       6915
# =================================================================
# Total params: 788,867
# Trainable params: 788,867
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.compile(optimizer='adam', loss='mse')  # binary_crossentropy

# %% [markdown]
# <h3>訓練模型</h3>

# %%
checkpointer = ModelCheckpoint(
    filepath='CNN-C-0-256-128-Full.hdf5', 
    monitor="val_loss", verbose=1, 
    save_best_only=True, mode='auto'
)

earlyStop = EarlyStopping(monitor='val_loss', patience=50)

# %%
num_of_epoch = 512
num_of_batch_size = 8

# %%
score = autoencoder.fit(x_train, x_train,
                        epochs=num_of_epoch,
                        batch_size=num_of_batch_size,
                        shuffle=True,
                        validation_data=(x_test, x_test),
                        callbacks=[checkpointer, earlyStop]
                       )
# Out:
# Epoch 1/512
#    2/2526 [..............................] - ETA: 1:44 - loss: 0.0181WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0259s vs `on_train_batch_end` time: 0.0571s). Check your callbacks.
# 2526/2526 [==============================] - ETA: 0s - loss: 4.2582e-04
# Epoch 00001: val_loss improved from inf to 0.00024, saving model to CNN-C-0-256-128-Full.hdf5
# 2526/2526 [==============================] - 225s 89ms/step - loss: 4.2582e-04 - val_loss: 2.4261e-04
# Epoch 2/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 2.3879e-04
# Epoch 00002: val_loss improved from 0.00024 to 0.00019, saving model to CNN-C-0-256-128-Full.hdf5
# 2526/2526 [==============================] - 222s 88ms/step - loss: 2.3880e-04 - val_loss: 1.9459e-04
# Epoch 3/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 2.0139e-04
# Epoch 00003: val_loss improved from 0.00019 to 0.00017, saving model to CNN-C-0-256-128-Full.hdf5
# 2526/2526 [==============================] - 224s 89ms/step - loss: 2.0138e-04 - val_loss: 1.7472e-04
# Epoch 4/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.7632e-04
# Epoch 00004: val_loss improved from 0.00017 to 0.00016, saving model to CNN-C-0-256-128-Full.hdf5
# 2526/2526 [==============================] - 226s 90ms/step - loss: 1.7631e-04 - val_loss: 1.5916e-04
# Epoch 5/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.6498e-04
# Epoch 00005: val_loss improved from 0.00016 to 0.00015, saving model to CNN-C-0-256-128-Full.hdf5
# 2526/2526 [==============================] - 228s 90ms/step - loss: 1.6499e-04 - val_loss: 1.4754e-04
# Epoch 6/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.5417e-04
# Epoch 00006: val_loss improved from 0.00015 to 0.00014, saving model to CNN-C-0-256-128-Full.hdf5
# 2526/2526 [==============================] - 228s 90ms/step - loss: 1.5417e-04 - val_loss: 1.4249e-04
# Epoch 7/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.4888e-04
# Epoch 00007: val_loss did not improve from 0.00014
# 2526/2526 [==============================] - 228s 90ms/step - loss: 1.4888e-04 - val_loss: 1.4321e-04
# Epoch 8/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.4413e-04
# Epoch 00008: val_loss improved from 0.00014 to 0.00014, saving model to CNN-C-0-256-128-Full.hdf5
# 2526/2526 [==============================] - 228s 90ms/step - loss: 1.4412e-04 - val_loss: 1.4206e-04
# Epoch 9/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.4351e-04
# Epoch 00009: val_loss improved from 0.00014 to 0.00013, saving model to CNN-C-0-256-128-Full.hdf5
# 2526/2526 [==============================] - 227s 90ms/step - loss: 1.4349e-04 - val_loss: 1.3387e-04
# Epoch 10/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.3971e-04
# Epoch 00010: val_loss did not improve from 0.00013
# 2526/2526 [==============================] - 227s 90ms/step - loss: 1.3972e-04 - val_loss: 1.3742e-04
# Epoch 11/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.3704e-04
# Epoch 00011: val_loss did not improve from 0.00013
# 2526/2526 [==============================] - 227s 90ms/step - loss: 1.3704e-04 - val_loss: 1.4020e-04
# Epoch 12/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.3527e-04
# Epoch 00012: val_loss improved from 0.00013 to 0.00013, saving model to CNN-C-0-256-128-Full.hdf5
# 2526/2526 [==============================] - 227s 90ms/step - loss: 1.3527e-04 - val_loss: 1.2611e-04
# Epoch 13/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.3361e-04
# Epoch 00013: val_loss did not improve from 0.00013
# 2526/2526 [==============================] - 227s 90ms/step - loss: 1.3361e-04 - val_loss: 1.3365e-04
# Epoch 14/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.3199e-04
# Epoch 00014: val_loss did not improve from 0.00013
# 2526/2526 [==============================] - 227s 90ms/step - loss: 1.3199e-04 - val_loss: 1.4236e-04
# Epoch 15/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.2951e-04
# Epoch 00015: val_loss did not improve from 0.00013
# 2526/2526 [==============================] - 227s 90ms/step - loss: 1.2952e-04 - val_loss: 1.5343e-04
# Epoch 16/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.2976e-04
# Epoch 00016: val_loss did not improve from 0.00013
# 2526/2526 [==============================] - 227s 90ms/step - loss: 1.2978e-04 - val_loss: 1.6069e-04
# Epoch 17/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.2668e-04
# Epoch 00017: val_loss did not improve from 0.00013
# 2526/2526 [==============================] - 227s 90ms/step - loss: 1.2670e-04 - val_loss: 1.3955e-04
# Epoch 18/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.2542e-04
# Epoch 00018: val_loss improved from 0.00013 to 0.00012, saving model to CNN-C-0-256-128-Full.hdf5
# 2526/2526 [==============================] - 227s 90ms/step - loss: 1.2541e-04 - val_loss: 1.1850e-04
# Epoch 19/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.2513e-04
# Epoch 00019: val_loss improved from 0.00012 to 0.00012, saving model to CNN-C-0-256-128-Full.hdf5
# 2526/2526 [==============================] - 227s 90ms/step - loss: 1.2513e-04 - val_loss: 1.1693e-04
# Epoch 20/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.2531e-04
# Epoch 00020: val_loss did not improve from 0.00012
# 2526/2526 [==============================] - 227s 90ms/step - loss: 1.2531e-04 - val_loss: 1.1825e-04
# Epoch 21/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.2341e-04
# Epoch 00021: val_loss improved from 0.00012 to 0.00012, saving model to CNN-C-0-256-128-Full.hdf5
# 2526/2526 [==============================] - 227s 90ms/step - loss: 1.2340e-04 - val_loss: 1.1652e-04
# Epoch 22/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.2464e-04
# Epoch 00022: val_loss did not improve from 0.00012
# 2526/2526 [==============================] - 227s 90ms/step - loss: 1.2465e-04 - val_loss: 1.2296e-04
# Epoch 23/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.2578e-04
# Epoch 00023: val_loss did not improve from 0.00012
# 2526/2526 [==============================] - 227s 90ms/step - loss: 1.2578e-04 - val_loss: 1.2314e-04
# Epoch 24/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.2252e-04
# Epoch 00024: val_loss did not improve from 0.00012
# 2526/2526 [==============================] - 227s 90ms/step - loss: 1.2251e-04 - val_loss: 1.2805e-04
# Epoch 25/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.2148e-04
# Epoch 00025: val_loss did not improve from 0.00012
# 2526/2526 [==============================] - 227s 90ms/step - loss: 1.2149e-04 - val_loss: 1.2073e-04
# Epoch 26/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.2176e-04
# Epoch 00026: val_loss improved from 0.00012 to 0.00012, saving model to CNN-C-0-256-128-Full.hdf5
# 2526/2526 [==============================] - 227s 90ms/step - loss: 1.2176e-04 - val_loss: 1.1605e-04
# Epoch 27/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.2106e-04
# Epoch 00027: val_loss improved from 0.00012 to 0.00011, saving model to CNN-C-0-256-128-Full.hdf5
# 2526/2526 [==============================] - 227s 90ms/step - loss: 1.2106e-04 - val_loss: 1.1423e-04
# Epoch 28/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.2055e-04
# Epoch 00028: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 227s 90ms/step - loss: 1.2055e-04 - val_loss: 1.1894e-04
# Epoch 29/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.2168e-04
# Epoch 00029: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 227s 90ms/step - loss: 1.2169e-04 - val_loss: 1.4579e-04
# Epoch 30/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.2014e-04
# Epoch 00030: val_loss improved from 0.00011 to 0.00011, saving model to CNN-C-0-256-128-Full.hdf5
# 2526/2526 [==============================] - 227s 90ms/step - loss: 1.2014e-04 - val_loss: 1.1371e-04
# Epoch 31/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1905e-04
# Epoch 00031: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 227s 90ms/step - loss: 1.1905e-04 - val_loss: 1.1472e-04
# Epoch 32/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1862e-04
# Epoch 00032: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 218s 86ms/step - loss: 1.1861e-04 - val_loss: 1.1653e-04
# Epoch 33/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1772e-04
# Epoch 00033: val_loss improved from 0.00011 to 0.00011, saving model to CNN-C-0-256-128-Full.hdf5
# 2526/2526 [==============================] - 219s 87ms/step - loss: 1.1773e-04 - val_loss: 1.1132e-04
# Epoch 34/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1702e-04
# Epoch 00034: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 218s 86ms/step - loss: 1.1702e-04 - val_loss: 1.1336e-04
# Epoch 35/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1712e-04
# Epoch 00035: val_loss improved from 0.00011 to 0.00011, saving model to CNN-C-0-256-128-Full.hdf5
# 2526/2526 [==============================] - 218s 86ms/step - loss: 1.1711e-04 - val_loss: 1.1100e-04
# Epoch 36/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1604e-04
# Epoch 00036: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 219s 87ms/step - loss: 1.1603e-04 - val_loss: 1.1966e-04
# Epoch 37/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.3719e-04
# Epoch 00037: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 218s 86ms/step - loss: 1.3720e-04 - val_loss: 1.4479e-04
# Epoch 38/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.2917e-04
# Epoch 00038: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 218s 86ms/step - loss: 1.2917e-04 - val_loss: 1.1985e-04
# Epoch 39/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.2521e-04
# Epoch 00039: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 218s 86ms/step - loss: 1.2521e-04 - val_loss: 1.2074e-04
# Epoch 40/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.2349e-04
# Epoch 00040: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 218s 86ms/step - loss: 1.2348e-04 - val_loss: 1.1971e-04
# Epoch 41/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.2103e-04
# Epoch 00041: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 218s 86ms/step - loss: 1.2102e-04 - val_loss: 1.1671e-04
# Epoch 42/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.2102e-04
# Epoch 00042: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 218s 86ms/step - loss: 1.2101e-04 - val_loss: 1.1773e-04
# Epoch 43/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1989e-04
# Epoch 00043: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 218s 86ms/step - loss: 1.1988e-04 - val_loss: 1.2816e-04
# Epoch 44/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1891e-04
# Epoch 00044: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 218s 86ms/step - loss: 1.1893e-04 - val_loss: 1.2745e-04
# Epoch 45/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1788e-04
# Epoch 00045: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 218s 86ms/step - loss: 1.1787e-04 - val_loss: 1.1333e-04
# Epoch 46/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1692e-04
# Epoch 00046: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 218s 86ms/step - loss: 1.1692e-04 - val_loss: 1.1201e-04
# Epoch 47/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1717e-04
# Epoch 00047: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 218s 86ms/step - loss: 1.1716e-04 - val_loss: 1.1402e-04
# Epoch 48/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1874e-04
# Epoch 00048: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 218s 86ms/step - loss: 1.1874e-04 - val_loss: 1.1260e-04
# Epoch 49/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1762e-04
# Epoch 00049: val_loss improved from 0.00011 to 0.00011, saving model to CNN-C-0-256-128-Full.hdf5
# 2526/2526 [==============================] - 218s 86ms/step - loss: 1.1762e-04 - val_loss: 1.1097e-04
# Epoch 50/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1608e-04
# Epoch 00050: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 218s 86ms/step - loss: 1.1608e-04 - val_loss: 1.2699e-04
# Epoch 51/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1631e-04
# Epoch 00051: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 218s 86ms/step - loss: 1.1631e-04 - val_loss: 1.1192e-04
# Epoch 52/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1612e-04
# Epoch 00052: val_loss improved from 0.00011 to 0.00011, saving model to CNN-C-0-256-128-Full.hdf5
# 2526/2526 [==============================] - 218s 86ms/step - loss: 1.1612e-04 - val_loss: 1.0984e-04
# Epoch 53/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1547e-04
# Epoch 00053: val_loss improved from 0.00011 to 0.00011, saving model to CNN-C-0-256-128-Full.hdf5
# 2526/2526 [==============================] - 218s 86ms/step - loss: 1.1547e-04 - val_loss: 1.0923e-04
# Epoch 54/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1520e-04
# Epoch 00054: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 218s 86ms/step - loss: 1.1519e-04 - val_loss: 1.1000e-04
# Epoch 55/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1467e-04
# Epoch 00055: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 218s 86ms/step - loss: 1.1467e-04 - val_loss: 1.1020e-04
# Epoch 56/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1582e-04
# Epoch 00056: val_loss improved from 0.00011 to 0.00011, saving model to CNN-C-0-256-128-Full.hdf5
# 2526/2526 [==============================] - 218s 86ms/step - loss: 1.1581e-04 - val_loss: 1.0885e-04
# Epoch 57/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1455e-04
# Epoch 00057: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 218s 86ms/step - loss: 1.1455e-04 - val_loss: 1.2069e-04
# Epoch 58/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1400e-04
# Epoch 00058: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 218s 86ms/step - loss: 1.1400e-04 - val_loss: 1.1127e-04
# Epoch 59/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1327e-04
# Epoch 00059: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 218s 86ms/step - loss: 1.1327e-04 - val_loss: 1.0949e-04
# Epoch 60/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1416e-04
# Epoch 00060: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 218s 86ms/step - loss: 1.1415e-04 - val_loss: 1.1413e-04
# Epoch 61/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1289e-04
# Epoch 00061: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1289e-04 - val_loss: 1.3372e-04
# Epoch 62/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1300e-04
# Epoch 00062: val_loss improved from 0.00011 to 0.00011, saving model to CNN-C-0-256-128-Full.hdf5
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1299e-04 - val_loss: 1.0791e-04
# Epoch 63/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1261e-04
# Epoch 00063: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1262e-04 - val_loss: 1.1310e-04
# Epoch 64/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1426e-04
# Epoch 00064: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1426e-04 - val_loss: 1.1765e-04
# Epoch 65/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1346e-04
# Epoch 00065: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1347e-04 - val_loss: 1.6173e-04
# Epoch 66/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1299e-04
# Epoch 00066: val_loss improved from 0.00011 to 0.00011, saving model to CNN-C-0-256-128-Full.hdf5
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1298e-04 - val_loss: 1.0749e-04
# Epoch 67/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.2460e-04
# Epoch 00067: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.2460e-04 - val_loss: 1.2501e-04
# Epoch 68/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.2371e-04
# Epoch 00068: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.2371e-04 - val_loss: 1.1556e-04
# Epoch 69/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.2096e-04
# Epoch 00069: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.2095e-04 - val_loss: 1.1445e-04
# Epoch 70/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.2024e-04
# Epoch 00070: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.2024e-04 - val_loss: 1.1490e-04
# Epoch 71/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.2027e-04
# Epoch 00071: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.2027e-04 - val_loss: 1.2291e-04
# Epoch 72/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.2026e-04
# Epoch 00072: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.2026e-04 - val_loss: 1.1611e-04
# Epoch 73/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1991e-04
# Epoch 00073: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1991e-04 - val_loss: 1.2644e-04
# Epoch 74/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1921e-04
# Epoch 00074: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1924e-04 - val_loss: 2.0874e-04
# Epoch 75/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1923e-04
# Epoch 00075: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1924e-04 - val_loss: 1.1532e-04
# Epoch 76/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1984e-04
# Epoch 00076: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1984e-04 - val_loss: 1.3389e-04
# Epoch 77/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1977e-04
# Epoch 00077: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1976e-04 - val_loss: 1.1453e-04
# Epoch 78/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1763e-04
# Epoch 00078: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1763e-04 - val_loss: 1.1178e-04
# Epoch 79/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1696e-04
# Epoch 00079: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1696e-04 - val_loss: 1.1432e-04
# Epoch 80/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1607e-04
# Epoch 00080: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1606e-04 - val_loss: 1.1365e-04
# Epoch 81/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1706e-04
# Epoch 00081: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1707e-04 - val_loss: 1.1987e-04
# Epoch 82/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1563e-04
# Epoch 00082: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1564e-04 - val_loss: 1.1170e-04
# Epoch 83/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1512e-04
# Epoch 00083: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1512e-04 - val_loss: 1.1060e-04
# Epoch 84/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1680e-04
# Epoch 00084: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1680e-04 - val_loss: 1.1206e-04
# Epoch 85/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1460e-04
# Epoch 00085: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1459e-04 - val_loss: 1.1280e-04
# Epoch 86/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1532e-04
# Epoch 00086: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1532e-04 - val_loss: 1.1730e-04
# Epoch 87/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1412e-04
# Epoch 00087: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1412e-04 - val_loss: 1.1116e-04
# Epoch 88/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1498e-04
# Epoch 00088: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1497e-04 - val_loss: 1.1019e-04
# Epoch 89/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1424e-04
# Epoch 00089: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1424e-04 - val_loss: 1.0800e-04
# Epoch 90/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1431e-04
# Epoch 00090: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1430e-04 - val_loss: 1.2580e-04
# Epoch 91/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1455e-04
# Epoch 00091: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1455e-04 - val_loss: 1.2074e-04
# Epoch 92/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1469e-04
# Epoch 00092: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1468e-04 - val_loss: 1.1416e-04
# Epoch 93/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1401e-04
# Epoch 00093: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1400e-04 - val_loss: 1.0859e-04
# Epoch 94/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1343e-04
# Epoch 00094: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1344e-04 - val_loss: 1.0887e-04
# Epoch 95/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1337e-04
# Epoch 00095: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1336e-04 - val_loss: 1.2680e-04
# Epoch 96/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1294e-04
# Epoch 00096: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1295e-04 - val_loss: 1.0825e-04
# Epoch 97/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1279e-04
# Epoch 00097: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1280e-04 - val_loss: 1.3914e-04
# Epoch 98/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1281e-04
# Epoch 00098: val_loss improved from 0.00011 to 0.00011, saving model to CNN-C-0-256-128-Full.hdf5
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1281e-04 - val_loss: 1.0721e-04
# Epoch 99/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1873e-04
# Epoch 00099: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1872e-04 - val_loss: 1.1641e-04
# Epoch 100/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1827e-04
# Epoch 00100: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 215s 85ms/step - loss: 1.1827e-04 - val_loss: 1.6134e-04
# Epoch 101/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1636e-04
# Epoch 00101: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1636e-04 - val_loss: 1.1040e-04
# Epoch 102/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1521e-04
# Epoch 00102: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1520e-04 - val_loss: 1.1114e-04
# Epoch 103/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1383e-04
# Epoch 00103: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1383e-04 - val_loss: 1.1290e-04
# Epoch 104/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1425e-04
# Epoch 00104: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1426e-04 - val_loss: 1.0876e-04
# Epoch 105/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1308e-04
# Epoch 00105: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1308e-04 - val_loss: 1.0826e-04
# Epoch 106/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1344e-04
# Epoch 00106: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1343e-04 - val_loss: 1.0736e-04
# Epoch 107/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1222e-04
# Epoch 00107: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1221e-04 - val_loss: 1.0747e-04
# Epoch 108/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1234e-04
# Epoch 00108: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1234e-04 - val_loss: 1.1943e-04
# Epoch 109/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1239e-04
# Epoch 00109: val_loss improved from 0.00011 to 0.00011, saving model to CNN-C-0-256-128-Full.hdf5
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1238e-04 - val_loss: 1.0678e-04
# Epoch 110/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1230e-04
# Epoch 00110: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1230e-04 - val_loss: 1.1765e-04
# Epoch 111/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1354e-04
# Epoch 00111: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1354e-04 - val_loss: 1.0851e-04
# Epoch 112/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1220e-04
# Epoch 00112: val_loss improved from 0.00011 to 0.00011, saving model to CNN-C-0-256-128-Full.hdf5
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1219e-04 - val_loss: 1.0626e-04
# Epoch 113/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1201e-04
# Epoch 00113: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1202e-04 - val_loss: 1.1219e-04
# Epoch 114/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1168e-04
# Epoch 00114: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1168e-04 - val_loss: 1.0760e-04
# Epoch 115/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1202e-04
# Epoch 00115: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1202e-04 - val_loss: 1.0919e-04
# Epoch 116/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1119e-04
# Epoch 00116: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1119e-04 - val_loss: 1.1814e-04
# Epoch 117/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1118e-04
# Epoch 00117: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1118e-04 - val_loss: 1.0645e-04
# Epoch 118/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1087e-04
# Epoch 00118: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1086e-04 - val_loss: 1.0755e-04
# Epoch 119/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1097e-04
# Epoch 00119: val_loss improved from 0.00011 to 0.00011, saving model to CNN-C-0-256-128-Full.hdf5
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1096e-04 - val_loss: 1.0591e-04
# Epoch 120/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1419e-04
# Epoch 00120: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1418e-04 - val_loss: 1.1224e-04
# Epoch 121/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1345e-04
# Epoch 00121: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1346e-04 - val_loss: 1.1036e-04
# Epoch 122/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1587e-04
# Epoch 00122: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1587e-04 - val_loss: 1.1499e-04
# Epoch 123/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1406e-04
# Epoch 00123: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1406e-04 - val_loss: 1.0829e-04
# Epoch 124/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1309e-04
# Epoch 00124: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1309e-04 - val_loss: 1.0937e-04
# Epoch 125/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1187e-04
# Epoch 00125: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1186e-04 - val_loss: 1.0894e-04
# Epoch 126/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1223e-04
# Epoch 00126: val_loss improved from 0.00011 to 0.00011, saving model to CNN-C-0-256-128-Full.hdf5
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1223e-04 - val_loss: 1.0568e-04
# Epoch 127/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1157e-04
# Epoch 00127: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1156e-04 - val_loss: 1.0711e-04
# Epoch 128/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1186e-04
# Epoch 00128: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1187e-04 - val_loss: 1.1193e-04
# Epoch 129/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1141e-04
# Epoch 00129: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1141e-04 - val_loss: 1.2280e-04
# Epoch 130/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1219e-04
# Epoch 00130: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1219e-04 - val_loss: 1.1646e-04
# Epoch 131/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1060e-04
# Epoch 00131: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1065e-04 - val_loss: 1.9701e-04
# Epoch 132/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1159e-04
# Epoch 00132: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1159e-04 - val_loss: 1.1511e-04
# Epoch 133/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1058e-04
# Epoch 00133: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1059e-04 - val_loss: 1.0896e-04
# Epoch 134/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1070e-04
# Epoch 00134: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1070e-04 - val_loss: 1.0582e-04
# Epoch 135/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1105e-04
# Epoch 00135: val_loss improved from 0.00011 to 0.00011, saving model to CNN-C-0-256-128-Full.hdf5
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1104e-04 - val_loss: 1.0520e-04
# Epoch 136/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1023e-04
# Epoch 00136: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1023e-04 - val_loss: 1.0733e-04
# Epoch 137/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1038e-04
# Epoch 00137: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1038e-04 - val_loss: 1.0950e-04
# Epoch 138/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1067e-04
# Epoch 00138: val_loss did not improve from 0.00011
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1066e-04 - val_loss: 1.4311e-04
# Epoch 139/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1008e-04
# Epoch 00139: val_loss improved from 0.00011 to 0.00010, saving model to CNN-C-0-256-128-Full.hdf5
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1008e-04 - val_loss: 1.0382e-04
# Epoch 140/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.0978e-04
# Epoch 00140: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.0978e-04 - val_loss: 1.0697e-04
# Epoch 141/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1236e-04
# Epoch 00141: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1236e-04 - val_loss: 1.0736e-04
# Epoch 142/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1203e-04
# Epoch 00142: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1203e-04 - val_loss: 1.0750e-04
# Epoch 143/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1327e-04
# Epoch 00143: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1327e-04 - val_loss: 1.1208e-04
# Epoch 144/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1203e-04
# Epoch 00144: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1204e-04 - val_loss: 1.0885e-04
# Epoch 145/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1105e-04
# Epoch 00145: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1108e-04 - val_loss: 1.1509e-04
# Epoch 146/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1057e-04
# Epoch 00146: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1057e-04 - val_loss: 1.0596e-04
# Epoch 147/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1156e-04
# Epoch 00147: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1156e-04 - val_loss: 1.0623e-04
# Epoch 148/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1012e-04
# Epoch 00148: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1012e-04 - val_loss: 1.0671e-04
# Epoch 149/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1022e-04
# Epoch 00149: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1023e-04 - val_loss: 1.0859e-04
# Epoch 150/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1059e-04
# Epoch 00150: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1059e-04 - val_loss: 1.0984e-04
# Epoch 151/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1016e-04
# Epoch 00151: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1016e-04 - val_loss: 1.0912e-04
# Epoch 152/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1026e-04
# Epoch 00152: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1025e-04 - val_loss: 1.1759e-04
# Epoch 153/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1155e-04
# Epoch 00153: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1154e-04 - val_loss: 1.0834e-04
# Epoch 154/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1404e-04
# Epoch 00154: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1403e-04 - val_loss: 1.0998e-04
# Epoch 155/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1100e-04
# Epoch 00155: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1102e-04 - val_loss: 1.1732e-04
# Epoch 156/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1273e-04
# Epoch 00156: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1275e-04 - val_loss: 1.3208e-04
# Epoch 157/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1786e-04
# Epoch 00157: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1789e-04 - val_loss: 1.6723e-04
# Epoch 158/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.3256e-04
# Epoch 00158: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 215s 85ms/step - loss: 1.3256e-04 - val_loss: 1.2277e-04
# Epoch 159/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.2420e-04
# Epoch 00159: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 215s 85ms/step - loss: 1.2420e-04 - val_loss: 1.1747e-04
# Epoch 160/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.2214e-04
# Epoch 00160: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 215s 85ms/step - loss: 1.2213e-04 - val_loss: 1.1677e-04
# Epoch 161/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.2023e-04
# Epoch 00161: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 215s 85ms/step - loss: 1.2022e-04 - val_loss: 1.2148e-04
# Epoch 162/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1967e-04
# Epoch 00162: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1967e-04 - val_loss: 1.1594e-04
# Epoch 163/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1906e-04
# Epoch 00163: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1906e-04 - val_loss: 1.1321e-04
# Epoch 164/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1731e-04
# Epoch 00164: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 215s 85ms/step - loss: 1.1731e-04 - val_loss: 1.1426e-04
# Epoch 165/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1931e-04
# Epoch 00165: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1930e-04 - val_loss: 1.2024e-04
# Epoch 166/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1926e-04
# Epoch 00166: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1926e-04 - val_loss: 1.1291e-04
# Epoch 167/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1821e-04
# Epoch 00167: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1821e-04 - val_loss: 1.1687e-04
# Epoch 168/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1685e-04
# Epoch 00168: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 215s 85ms/step - loss: 1.1684e-04 - val_loss: 1.2054e-04
# Epoch 169/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1684e-04
# Epoch 00169: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1683e-04 - val_loss: 1.1151e-04
# Epoch 170/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1743e-04
# Epoch 00170: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1742e-04 - val_loss: 1.1429e-04
# Epoch 171/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1659e-04
# Epoch 00171: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1658e-04 - val_loss: 1.1076e-04
# Epoch 172/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1579e-04
# Epoch 00172: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1579e-04 - val_loss: 1.1028e-04
# Epoch 173/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1769e-04
# Epoch 00173: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1769e-04 - val_loss: 1.1267e-04
# Epoch 174/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1717e-04
# Epoch 00174: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1717e-04 - val_loss: 1.1534e-04
# Epoch 175/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1446e-04
# Epoch 00175: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1446e-04 - val_loss: 1.0987e-04
# Epoch 176/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1472e-04
# Epoch 00176: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 214s 85ms/step - loss: 1.1472e-04 - val_loss: 1.0963e-04
# Epoch 177/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1459e-04
# Epoch 00177: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1459e-04 - val_loss: 1.1485e-04
# Epoch 178/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1413e-04
# Epoch 00178: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1413e-04 - val_loss: 1.1087e-04
# Epoch 179/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1386e-04
# Epoch 00179: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1386e-04 - val_loss: 1.1106e-04
# Epoch 180/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1418e-04
# Epoch 00180: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1419e-04 - val_loss: 1.1165e-04
# Epoch 181/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1413e-04
# Epoch 00181: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1413e-04 - val_loss: 1.3319e-04
# Epoch 182/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1313e-04
# Epoch 00182: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1314e-04 - val_loss: 1.0930e-04
# Epoch 183/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1364e-04
# Epoch 00183: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 215s 85ms/step - loss: 1.1364e-04 - val_loss: 1.1019e-04
# Epoch 184/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1377e-04
# Epoch 00184: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1376e-04 - val_loss: 1.0803e-04
# Epoch 185/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1345e-04
# Epoch 00185: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1344e-04 - val_loss: 1.1482e-04
# Epoch 186/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1678e-04
# Epoch 00186: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1676e-04 - val_loss: 1.1083e-04
# Epoch 187/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1444e-04
# Epoch 00187: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1445e-04 - val_loss: 1.1362e-04
# Epoch 188/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1459e-04
# Epoch 00188: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1458e-04 - val_loss: 1.1024e-04
# Epoch 189/512
# 2525/2526 [============================>.] - ETA: 0s - loss: 1.1481e-04
# Epoch 00189: val_loss did not improve from 0.00010
# 2526/2526 [==============================] - 216s 85ms/step - loss: 1.1481e-04 - val_loss: 1.1045e-04

# %% [markdown]
# <h3>模型訓練績效</h3>

# %%
best_iteration = numpy.argmin(score.history['val_loss']) + 1

val_scores = score.history['val_loss'][0:best_iteration]
train_scores = score.history['loss'][0:best_iteration]

fig, ax = plt.subplots(dpi=120)

ax.plot(val_scores, label='val_loss')
ax.plot(train_scores, label='train_loss')

plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# <h3>產生假圖</h3>

# %%
encoder = Model(inputs=autoencoder.input, outputs=autoencoder.get_layer("latent").output)

encoded_imgs = encoder.predict(x_test)
print(encoded_imgs.shape)

encoded_imgs = encoded_imgs.reshape((len(encoded_imgs), max_dim[0], max_dim[1], 1))
# Out:
# (5052, 32, 32, 64)

# %%
decoded_imgs = autoencoder.predict(x_test)

# %%
x_test.shape, encoded_imgs.shape, decoded_imgs.shape
# Out:
# ((5052, 256, 256, 3), (5052, 256, 256, 1), (5052, 256, 256, 3))

# %% [markdown]
# <h3>隨機顯示抽象圖與假圖</h3>

# %%
i = numpy.random.randint(0, x_test.shape[0], 1)[0]

# %%
fig, ax = plt.subplots(dpi=120)

ax.imshow(x_test[i].reshape(max_dim))
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

plt.show()

# %%
fig, ax = plt.subplots(dpi=120)

ax.imshow(decoded_imgs[i].reshape(max_dim), cmap=plt.cm.binary)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

plt.show()

# %%
fig, ax = plt.subplots(dpi=120)

diff_image = x_test[i] - decoded_imgs[i]
diff_image_min = diff_image.min()
diff_image_max = diff_image.max()
diff_image_val = (diff_image - diff_image_min) / (diff_image_max - diff_image_min)

ax.imshow(diff_image_val.reshape(max_dim), cmap=plt.cm.binary)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

plt.show()

# %% [markdown]
# <h3>顯示原圖與假圖</h3>

# %%
fig, (ax0, ax2, ax3) = plt.subplots(dpi=120, ncols=3)

ax0.imshow(x_test[i].reshape(max_dim), cmap=plt.cm.binary)
ax0.get_xaxis().set_visible(False)
ax0.get_yaxis().set_visible(False)

ax2.imshow(decoded_imgs[i].reshape(max_dim), cmap=plt.cm.binary)
ax2.get_xaxis().set_visible(False)
ax2.get_yaxis().set_visible(False)

diff_image = x_test[i] - decoded_imgs[i]
diff_image_min = diff_image.min()
diff_image_max = diff_image.max()
diff_image_val = (diff_image - diff_image_min) / (diff_image_max - diff_image_min)

ax3.imshow(diff_image_val.reshape(max_dim), cmap=plt.cm.binary)
ax3.get_xaxis().set_visible(False)
ax3.get_yaxis().set_visible(False)

plt.tight_layout()
plt.show()

# %%
def benchmark(my_diff_image):
    diff = 0.0
    
    for i in range(3):
        diff += numpy.sum(numpy.square(diff_image[i]))
        
    return diff**0.5

# %%
benchmark(diff_image)
# Out:
# 0.28848649642565977

# %%
faint_image_files = glob('%s/F*.jpg' % 'images/objects/faint')

# %%
my_faint_images = []

for image_file in faint_image_files[:24]:
    _image_file = image_file.replace('\\', '/')

    _fish_image = read_image_file(_image_file, enhance_flag)

    my_faint_images.append(numpy.reshape(_fish_image, max_dim))

my_faint_images = numpy.array(my_faint_images)

# %%
my_faint_images = my_faint_images.astype('float32') / 255.
my_faint_images = numpy.reshape(my_faint_images, (my_faint_images.shape[0],) + max_dim)

# %%
my_faint_images.shape
# Out:
# (24, 256, 256, 3)

# %% [markdown]
# <h3>產生假圖</h3>

# %%
encoding_dim = (32, 32, 64)

# %%
faint_encoder = Model(inputs=autoencoder.input, outputs=autoencoder.get_layer("latent").output)

faint_encoded_imgs = faint_encoder.predict(my_faint_images)
faint_encoded_imgs = faint_encoded_imgs.reshape((len(faint_encoded_imgs), max_dim[0], max_dim[1], 1))

# %%
faint_decoded_imgs = autoencoder.predict(my_faint_images)

# %% [markdown]
# <h3>顯示原圖與假圖</h3>

# %%
def find_faint_file_pos(my_image_id=None):
    pos = -1
    
    if my_image_id is None:
        pos = numpy.random.randint(0, my_faint_images.shape[0], 1)[0]
    else:
        for j in range(len(faint_image_files)):
            image_file = faint_image_files[j]
            if my_image_id in image_file:
                pos = j
                break
            
    if pos == -1:
        pos = numpy.random.randint(0, my_faint_images.shape[0], 1)[0]
        
    return pos

# %%
i = find_faint_file_pos()

# %%
fig, (ax0, ax1, ax2) = plt.subplots(dpi=240, ncols=3)

ax0.imshow(my_faint_images[i].reshape(max_dim[0], max_dim[1], max_dim[2]))
ax0.get_xaxis().set_visible(False)
ax0.get_yaxis().set_visible(False)

ax1.imshow(faint_decoded_imgs[i].reshape(max_dim[0], max_dim[1], max_dim[2]))
ax1.get_xaxis().set_visible(False)
ax1.get_yaxis().set_visible(False)

faint_diff_image = my_faint_images[i] - faint_decoded_imgs[i]
faint_diff_image_min = faint_diff_image.min()
faint_diff_image_max = faint_diff_image.max()
faint_diff_image_val = (faint_diff_image - faint_diff_image_min) / (faint_diff_image_max - faint_diff_image_min)

ax2.imshow(faint_diff_image_val.reshape(max_dim), cmap=plt.cm.binary)
ax2.get_xaxis().set_visible(False)
ax2.get_yaxis().set_visible(False)

plt.tight_layout()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
fig, ax1 = plt.subplots(dpi=120)

ax1.imshow(faint_decoded_imgs[i].reshape(max_dim))
ax1.get_xaxis().set_visible(False)
ax1.get_yaxis().set_visible(False)

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
benchmark(faint_diff_image)
# Out:
# 0.28848649642565977
