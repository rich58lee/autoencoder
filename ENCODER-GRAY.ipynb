# %% [markdown]
# <h3>輸入原影像，經過壓縮轉換，再由轉換壓縮碼，還原成類原圖</h3>

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# %%
from glob import glob
import numpy

# %%
import cv2

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator

# %%
import keras
from keras import layers
from keras.models import Model
from keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from pylab import rcParams
from matplotlib import cm

# %% [markdown]
# <h3>環境設置</h3>

# %%
max_dim = (256, 256, 1)

kernel = numpy.array([[-1, -1, -1], [-1, 11, -1], [-1, -1, -1]])

alpha = 0.6 # Contrast control (1.0-3.0)
beta = 2 # Brightness control (0-100)

# %%
def read_image_file(my_image_file):
    global max_dim, kernel, alpha, beta
    
    _fish_image = cv2.imread(my_image_file, 0)
    _fish_image = cv2.filter2D(_fish_image, -1, kernel)
    _fish_image = cv2.convertScaleAbs(_fish_image.copy(), alpha=alpha, beta=beta)

    _fish_image = cv2.resize(_fish_image.copy(), max_dim[:2])
    
    return _fish_image

# %%
def show_image(my_image):
    global max_dim
    
    _my_image = numpy.reshape(my_image, max_dim)
    
    fig, ax = plt.subplots(dpi=120)
    
    ax.imshow(my_image, cmap='gray', interpolation='bicubic')
    ax.axis('off')
    
    plt.show()

# %% [markdown]
# <h3>載入魚影像檔</h3>

# %%
datagen = ImageDataGenerator(featurewise_center=True,
                             featurewise_std_normalization=True,
                             rotation_range=45,
                             width_shift_range=[0.1, 0.2],
                             height_shift_range=[0.1, 0.2],
                             horizontal_flip=True)

_fish_image = read_image_file('images/faint/F000234-00001.jpg')

fig, ax = plt.subplots(dpi=120, ncols=3)

ax[0].imshow(_fish_image, cmap='gray', interpolation='bicubic')
ax[0].axis('off')

_fish_img_data = img_to_array(_fish_image)    
_fish_img_data = numpy.expand_dims(_fish_img_data, 0)

it = datagen.flow(_fish_img_data, batch_size=1)

for i in range(1, 3):
    _batch = it.next()
    _generated_image = _batch[0].astype('uint8')
            
    ax[i].imshow(_generated_image, cmap='gray', interpolation='bicubic')
    ax[i].axis('off')
    
plt.tight_layout()
plt.show()
# Out:
# /home/solarwind/anaconda3/envs/tensorflow/lib/python3.8/site-packages/keras_preprocessing/image/image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /home/solarwind/anaconda3/envs/tensorflow/lib/python3.8/site-packages/keras_preprocessing/image/image_data_generator.py:728: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '

# %%
def load_data(image_path, train_ratio=0.8):
    global max_dim

    datagen = ImageDataGenerator(featurewise_center=True,
                                 featurewise_std_normalization=True,
                                 rotation_range=45,
                                 width_shift_range=[0.1, 0.2],
                                 height_shift_range=[0.1, 0.2],
                                 horizontal_flip=True
    )
    
    image_files = glob('%s/F*.jpg' % image_path)

    my_images = []

    for image_file in image_files:
        _image_file = image_file.replace('\\', '/')
        
        _fish_image = read_image_file(_image_file)
        
        my_images.append(numpy.reshape(_fish_image, max_dim))

        _fish_img_data = img_to_array(_fish_image)    
        _fish_img_data = numpy.expand_dims(_fish_img_data, 0)
        
        it = datagen.flow(_fish_img_data, batch_size=1)

        for i in range(10):
            _batch = it.next()
            _generated_image = _batch[0].astype('uint8')
            
            my_images.append(numpy.reshape(_generated_image, max_dim))

    my_images = numpy.array(my_images)
    numpy.random.shuffle(my_images)
    
    pos = int(my_images.shape[0] * train_ratio)
    return my_images[:pos], my_images[pos:]

# %%
x_train, x_test = load_data(image_path='images/train')

# %%
x_train.shape, x_test.shape
# Out:
# ((4488, 256, 256, 1), (1122, 256, 256, 1))

# %%
show_image(x_train[numpy.random.randint(len(x_train))])

# %% [markdown]
# <h3>將 0 ~ 255 值域，轉換為: 0 ~ 1</h3>

# %%
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# %% [markdown]
# <h3>參數設置</h3>
# <p>$$壓縮率: \frac {{256}*{256}={65536}}{64} = 1024$$</p>

# %%
encoding_dim = (32, 32, 64)

# %% [markdown]
# <h3>建立模型</h3>

# %%
input_img = keras.Input(shape=max_dim, name='input')

# %%
x = layers.Conv2D(256, (3, 3), activation='relu', padding='same', name='Conv2D_256')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same', name='MaxPooling2D_256')(x)

# %%
x = layers.Conv2D(128, (3, 3), activation='relu', padding='same', name='Conv2D_128')(x)
x = layers.MaxPooling2D((2, 2), padding='same', name='MaxPooling2D_128')(x)

# %%
x = layers.Conv2D(64, (3, 3), activation='relu', padding='same', name='Conv2D_64')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same', name='encoded')(x)

# %%
x = layers.Conv2DTranspose(64, (3, 3), activation='relu', padding='same', name='Conv2DT_64')(encoded)
x = layers.UpSampling2D((2, 2), name='UpSampling2D_64')(x)

# %%
x = layers.Conv2DTranspose(128, (3, 3), activation='relu', padding='same', name='Conv2DT_128')(x)
x = layers.UpSampling2D((2, 2), name='UpSampling2D_128')(x)

# %%
x = layers.Conv2DTranspose(256, (3, 3), activation='relu', padding='same', name='Conv2DT_256')(x)
x = layers.UpSampling2D((2, 2), name='UpSampling2D_256')(x)

# %%
decoded = layers.Conv2D(1, (3, 3), padding='same', name='output')(x)

# %%
autoencoder = keras.Model(input_img, decoded)

# %%
autoencoder.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 256, 256, 1)]     0
# _________________________________________________________________
# Conv2D_256 (Conv2D)          (None, 256, 256, 256)     2560
# _________________________________________________________________
# MaxPooling2D_256 (MaxPooling (None, 128, 128, 256)     0
# _________________________________________________________________
# Conv2D_128 (Conv2D)          (None, 128, 128, 128)     295040
# _________________________________________________________________
# MaxPooling2D_128 (MaxPooling (None, 64, 64, 128)       0
# _________________________________________________________________
# Conv2D_64 (Conv2D)           (None, 64, 64, 64)        73792
# _________________________________________________________________
# encoded (MaxPooling2D)       (None, 32, 32, 64)        0
# _________________________________________________________________
# Conv2DT_64 (Conv2DTranspose) (None, 32, 32, 64)        36928
# _________________________________________________________________
# UpSampling2D_64 (UpSampling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# Conv2DT_128 (Conv2DTranspose (None, 64, 64, 128)       73856
# _________________________________________________________________
# UpSampling2D_128 (UpSampling (None, 128, 128, 128)     0
# _________________________________________________________________
# Conv2DT_256 (Conv2DTranspose (None, 128, 128, 256)     295168
# _________________________________________________________________
# UpSampling2D_256 (UpSampling (None, 256, 256, 256)     0
# _________________________________________________________________
# output (Conv2D)              (None, 256, 256, 1)       2305
# =================================================================
# Total params: 779,649
# Trainable params: 779,649
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.compile(optimizer='adam', loss='mse')  # binary_crossentropy

# %% [markdown]
# <h3>訓練模型</h3>

# %%
checkpointer = ModelCheckpoint(
    filepath='Fish-Gray.hdf5', 
    monitor="val_loss", verbose=1, 
    save_best_only=True, mode='auto'
)

earlyStop = EarlyStopping(monitor='val_loss', patience=12)

# %%
num_of_epoch = 128
num_of_batch_size = 16

# %%
score = autoencoder.fit(x_train, x_train,
                        epochs=num_of_epoch,
                        batch_size=num_of_batch_size,
                        shuffle=True,
                        validation_data=(x_test, x_test),
                        callbacks=[checkpointer, earlyStop]
                       )
# Out:
# Epoch 1/128
#   2/281 [..............................] - ETA: 21s - loss: 0.0461WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0561s vs `on_train_batch_end` time: 0.0975s). Check your callbacks.
# 281/281 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 00001: val_loss improved from inf to 0.00073, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 47s 169ms/step - loss: 0.0057 - val_loss: 7.2642e-04
# Epoch 2/128
# 281/281 [==============================] - ETA: 0s - loss: 6.2487e-04
# Epoch 00002: val_loss improved from 0.00073 to 0.00053, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 6.2487e-04 - val_loss: 5.3155e-04
# Epoch 3/128
# 281/281 [==============================] - ETA: 0s - loss: 5.1477e-04
# Epoch 00003: val_loss improved from 0.00053 to 0.00048, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 5.1477e-04 - val_loss: 4.8480e-04
# Epoch 4/128
# 281/281 [==============================] - ETA: 0s - loss: 4.6456e-04
# Epoch 00004: val_loss improved from 0.00048 to 0.00047, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 4.6456e-04 - val_loss: 4.7355e-04
# Epoch 5/128
# 281/281 [==============================] - ETA: 0s - loss: 4.2754e-04
# Epoch 00005: val_loss improved from 0.00047 to 0.00040, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 46s 165ms/step - loss: 4.2754e-04 - val_loss: 4.0328e-04
# Epoch 6/128
# 281/281 [==============================] - ETA: 0s - loss: 4.2787e-04
# Epoch 00006: val_loss did not improve from 0.00040
# 281/281 [==============================] - 46s 164ms/step - loss: 4.2787e-04 - val_loss: 4.2391e-04
# Epoch 7/128
# 281/281 [==============================] - ETA: 0s - loss: 4.0267e-04
# Epoch 00007: val_loss improved from 0.00040 to 0.00037, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 4.0267e-04 - val_loss: 3.7308e-04
# Epoch 8/128
# 281/281 [==============================] - ETA: 0s - loss: 3.8940e-04
# Epoch 00008: val_loss did not improve from 0.00037
# 281/281 [==============================] - 46s 164ms/step - loss: 3.8940e-04 - val_loss: 4.0722e-04
# Epoch 9/128
# 281/281 [==============================] - ETA: 0s - loss: 4.0143e-04
# Epoch 00009: val_loss improved from 0.00037 to 0.00036, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 4.0143e-04 - val_loss: 3.5786e-04
# Epoch 10/128
# 281/281 [==============================] - ETA: 0s - loss: 3.6241e-04
# Epoch 00010: val_loss improved from 0.00036 to 0.00036, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 46s 165ms/step - loss: 3.6241e-04 - val_loss: 3.5692e-04
# Epoch 11/128
# 281/281 [==============================] - ETA: 0s - loss: 3.7896e-04
# Epoch 00011: val_loss improved from 0.00036 to 0.00036, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 46s 165ms/step - loss: 3.7896e-04 - val_loss: 3.5527e-04
# Epoch 12/128
# 281/281 [==============================] - ETA: 0s - loss: 3.5564e-04
# Epoch 00012: val_loss did not improve from 0.00036
# 281/281 [==============================] - 46s 164ms/step - loss: 3.5564e-04 - val_loss: 4.8882e-04
# Epoch 13/128
# 281/281 [==============================] - ETA: 0s - loss: 3.4477e-04
# Epoch 00013: val_loss did not improve from 0.00036
# 281/281 [==============================] - 46s 164ms/step - loss: 3.4477e-04 - val_loss: 3.7866e-04
# Epoch 14/128
# 281/281 [==============================] - ETA: 0s - loss: 3.4806e-04
# Epoch 00014: val_loss improved from 0.00036 to 0.00033, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 46s 165ms/step - loss: 3.4806e-04 - val_loss: 3.2926e-04
# Epoch 15/128
# 281/281 [==============================] - ETA: 0s - loss: 3.4311e-04
# Epoch 00015: val_loss did not improve from 0.00033
# 281/281 [==============================] - 46s 164ms/step - loss: 3.4311e-04 - val_loss: 3.4566e-04
# Epoch 16/128
# 281/281 [==============================] - ETA: 0s - loss: 3.5290e-04
# Epoch 00016: val_loss improved from 0.00033 to 0.00032, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 46s 165ms/step - loss: 3.5290e-04 - val_loss: 3.1681e-04
# Epoch 17/128
# 281/281 [==============================] - ETA: 0s - loss: 3.2679e-04
# Epoch 00017: val_loss improved from 0.00032 to 0.00031, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 3.2679e-04 - val_loss: 3.1392e-04
# Epoch 18/128
# 281/281 [==============================] - ETA: 0s - loss: 3.3315e-04
# Epoch 00018: val_loss did not improve from 0.00031
# 281/281 [==============================] - 46s 165ms/step - loss: 3.3315e-04 - val_loss: 3.6899e-04
# Epoch 19/128
# 281/281 [==============================] - ETA: 0s - loss: 3.4508e-04
# Epoch 00019: val_loss did not improve from 0.00031
# 281/281 [==============================] - 46s 164ms/step - loss: 3.4508e-04 - val_loss: 3.1661e-04
# Epoch 20/128
# 281/281 [==============================] - ETA: 0s - loss: 3.0077e-04
# Epoch 00020: val_loss improved from 0.00031 to 0.00030, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 46s 165ms/step - loss: 3.0077e-04 - val_loss: 3.0335e-04
# Epoch 21/128
# 281/281 [==============================] - ETA: 0s - loss: 3.4005e-04
# Epoch 00021: val_loss did not improve from 0.00030
# 281/281 [==============================] - 46s 165ms/step - loss: 3.4005e-04 - val_loss: 3.0522e-04
# Epoch 22/128
# 281/281 [==============================] - ETA: 0s - loss: 3.1655e-04
# Epoch 00022: val_loss did not improve from 0.00030
# 281/281 [==============================] - 46s 164ms/step - loss: 3.1655e-04 - val_loss: 3.8403e-04
# Epoch 23/128
# 281/281 [==============================] - ETA: 0s - loss: 3.2933e-04
# Epoch 00023: val_loss improved from 0.00030 to 0.00030, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 46s 165ms/step - loss: 3.2933e-04 - val_loss: 2.9801e-04
# Epoch 24/128
# 281/281 [==============================] - ETA: 0s - loss: 3.0248e-04
# Epoch 00024: val_loss did not improve from 0.00030
# 281/281 [==============================] - 46s 164ms/step - loss: 3.0248e-04 - val_loss: 3.6162e-04
# Epoch 25/128
# 281/281 [==============================] - ETA: 0s - loss: 3.6367e-04
# Epoch 00025: val_loss did not improve from 0.00030
# 281/281 [==============================] - 46s 164ms/step - loss: 3.6367e-04 - val_loss: 3.0938e-04
# Epoch 26/128
# 281/281 [==============================] - ETA: 0s - loss: 2.9492e-04
# Epoch 00026: val_loss improved from 0.00030 to 0.00029, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 2.9492e-04 - val_loss: 2.9272e-04
# Epoch 27/128
# 281/281 [==============================] - ETA: 0s - loss: 3.1603e-04
# Epoch 00027: val_loss improved from 0.00029 to 0.00029, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 3.1603e-04 - val_loss: 2.8862e-04
# Epoch 28/128
# 281/281 [==============================] - ETA: 0s - loss: 2.9052e-04
# Epoch 00028: val_loss improved from 0.00029 to 0.00029, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 2.9052e-04 - val_loss: 2.8650e-04
# Epoch 29/128
# 281/281 [==============================] - ETA: 0s - loss: 3.0260e-04
# Epoch 00029: val_loss improved from 0.00029 to 0.00028, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 3.0260e-04 - val_loss: 2.8164e-04
# Epoch 30/128
# 281/281 [==============================] - ETA: 0s - loss: 2.7968e-04
# Epoch 00030: val_loss did not improve from 0.00028
# 281/281 [==============================] - 46s 164ms/step - loss: 2.7968e-04 - val_loss: 3.3455e-04
# Epoch 31/128
# 281/281 [==============================] - ETA: 0s - loss: 2.9676e-04
# Epoch 00031: val_loss improved from 0.00028 to 0.00027, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 2.9676e-04 - val_loss: 2.7447e-04
# Epoch 32/128
# 281/281 [==============================] - ETA: 0s - loss: 2.8437e-04
# Epoch 00032: val_loss improved from 0.00027 to 0.00027, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 2.8437e-04 - val_loss: 2.7409e-04
# Epoch 33/128
# 281/281 [==============================] - ETA: 0s - loss: 2.9569e-04
# Epoch 00033: val_loss did not improve from 0.00027
# 281/281 [==============================] - 46s 164ms/step - loss: 2.9569e-04 - val_loss: 4.0135e-04
# Epoch 34/128
# 281/281 [==============================] - ETA: 0s - loss: 2.7385e-04
# Epoch 00034: val_loss did not improve from 0.00027
# 281/281 [==============================] - 46s 164ms/step - loss: 2.7385e-04 - val_loss: 2.7568e-04
# Epoch 35/128
# 281/281 [==============================] - ETA: 0s - loss: 2.7697e-04
# Epoch 00035: val_loss improved from 0.00027 to 0.00027, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 2.7697e-04 - val_loss: 2.6694e-04
# Epoch 36/128
# 281/281 [==============================] - ETA: 0s - loss: 4.5021e-04
# Epoch 00036: val_loss did not improve from 0.00027
# 281/281 [==============================] - 46s 164ms/step - loss: 4.5021e-04 - val_loss: 3.9483e-04
# Epoch 37/128
# 281/281 [==============================] - ETA: 0s - loss: 3.3824e-04
# Epoch 00037: val_loss did not improve from 0.00027
# 281/281 [==============================] - 46s 164ms/step - loss: 3.3824e-04 - val_loss: 3.1154e-04
# Epoch 38/128
# 281/281 [==============================] - ETA: 0s - loss: 3.0406e-04
# Epoch 00038: val_loss did not improve from 0.00027
# 281/281 [==============================] - 46s 164ms/step - loss: 3.0406e-04 - val_loss: 2.9584e-04
# Epoch 39/128
# 281/281 [==============================] - ETA: 0s - loss: 2.9204e-04
# Epoch 00039: val_loss did not improve from 0.00027
# 281/281 [==============================] - 46s 164ms/step - loss: 2.9204e-04 - val_loss: 3.3012e-04
# Epoch 40/128
# 281/281 [==============================] - ETA: 0s - loss: 2.8903e-04
# Epoch 00040: val_loss did not improve from 0.00027
# 281/281 [==============================] - 46s 164ms/step - loss: 2.8903e-04 - val_loss: 2.8369e-04
# Epoch 41/128
# 281/281 [==============================] - ETA: 0s - loss: 2.7654e-04
# Epoch 00041: val_loss did not improve from 0.00027
# 281/281 [==============================] - 46s 164ms/step - loss: 2.7654e-04 - val_loss: 4.4840e-04
# Epoch 42/128
# 281/281 [==============================] - ETA: 0s - loss: 2.7921e-04
# Epoch 00042: val_loss did not improve from 0.00027
# 281/281 [==============================] - 46s 164ms/step - loss: 2.7921e-04 - val_loss: 2.6916e-04
# Epoch 43/128
# 281/281 [==============================] - ETA: 0s - loss: 2.7224e-04
# Epoch 00043: val_loss improved from 0.00027 to 0.00026, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 2.7224e-04 - val_loss: 2.6485e-04
# Epoch 44/128
# 281/281 [==============================] - ETA: 0s - loss: 2.9481e-04
# Epoch 00044: val_loss did not improve from 0.00026
# 281/281 [==============================] - 46s 164ms/step - loss: 2.9481e-04 - val_loss: 4.2382e-04
# Epoch 45/128
# 281/281 [==============================] - ETA: 0s - loss: 2.8351e-04
# Epoch 00045: val_loss did not improve from 0.00026
# 281/281 [==============================] - 46s 164ms/step - loss: 2.8351e-04 - val_loss: 2.6616e-04
# Epoch 46/128
# 281/281 [==============================] - ETA: 0s - loss: 2.6398e-04
# Epoch 00046: val_loss did not improve from 0.00026
# 281/281 [==============================] - 46s 164ms/step - loss: 2.6398e-04 - val_loss: 2.7063e-04
# Epoch 47/128
# 281/281 [==============================] - ETA: 0s - loss: 2.6480e-04
# Epoch 00047: val_loss did not improve from 0.00026
# 281/281 [==============================] - 46s 164ms/step - loss: 2.6480e-04 - val_loss: 2.9458e-04
# Epoch 48/128
# 281/281 [==============================] - ETA: 0s - loss: 2.6031e-04
# Epoch 00048: val_loss improved from 0.00026 to 0.00026, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 2.6031e-04 - val_loss: 2.5922e-04
# Epoch 49/128
# 281/281 [==============================] - ETA: 0s - loss: 2.6275e-04
# Epoch 00049: val_loss improved from 0.00026 to 0.00025, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 2.6275e-04 - val_loss: 2.5313e-04
# Epoch 50/128
# 281/281 [==============================] - ETA: 0s - loss: 2.6849e-04
# Epoch 00050: val_loss did not improve from 0.00025
# 281/281 [==============================] - 46s 164ms/step - loss: 2.6849e-04 - val_loss: 2.6400e-04
# Epoch 51/128
# 281/281 [==============================] - ETA: 0s - loss: 2.5413e-04
# Epoch 00051: val_loss did not improve from 0.00025
# 281/281 [==============================] - 46s 164ms/step - loss: 2.5413e-04 - val_loss: 2.6503e-04
# Epoch 52/128
# 281/281 [==============================] - ETA: 0s - loss: 2.5411e-04
# Epoch 00052: val_loss did not improve from 0.00025
# 281/281 [==============================] - 46s 164ms/step - loss: 2.5411e-04 - val_loss: 2.7031e-04
# Epoch 53/128
# 281/281 [==============================] - ETA: 0s - loss: 2.4975e-04
# Epoch 00053: val_loss improved from 0.00025 to 0.00025, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 2.4975e-04 - val_loss: 2.5082e-04
# Epoch 54/128
# 281/281 [==============================] - ETA: 0s - loss: 2.5233e-04
# Epoch 00054: val_loss improved from 0.00025 to 0.00025, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 2.5233e-04 - val_loss: 2.4537e-04
# Epoch 55/128
# 281/281 [==============================] - ETA: 0s - loss: 3.7320e-04
# Epoch 00055: val_loss did not improve from 0.00025
# 281/281 [==============================] - 46s 164ms/step - loss: 3.7320e-04 - val_loss: 3.4039e-04
# Epoch 56/128
# 281/281 [==============================] - ETA: 0s - loss: 3.0184e-04
# Epoch 00056: val_loss did not improve from 0.00025
# 281/281 [==============================] - 46s 164ms/step - loss: 3.0184e-04 - val_loss: 2.8863e-04
# Epoch 57/128
# 281/281 [==============================] - ETA: 0s - loss: 2.7411e-04
# Epoch 00057: val_loss did not improve from 0.00025
# 281/281 [==============================] - 46s 164ms/step - loss: 2.7411e-04 - val_loss: 2.7085e-04
# Epoch 58/128
# 281/281 [==============================] - ETA: 0s - loss: 2.6506e-04
# Epoch 00058: val_loss did not improve from 0.00025
# 281/281 [==============================] - 46s 164ms/step - loss: 2.6506e-04 - val_loss: 2.6241e-04
# Epoch 59/128
# 281/281 [==============================] - ETA: 0s - loss: 2.6376e-04
# Epoch 00059: val_loss did not improve from 0.00025
# 281/281 [==============================] - 46s 164ms/step - loss: 2.6376e-04 - val_loss: 2.5758e-04
# Epoch 60/128
# 281/281 [==============================] - ETA: 0s - loss: 2.5757e-04
# Epoch 00060: val_loss did not improve from 0.00025
# 281/281 [==============================] - 46s 164ms/step - loss: 2.5757e-04 - val_loss: 2.5444e-04
# Epoch 61/128
# 281/281 [==============================] - ETA: 0s - loss: 2.6006e-04
# Epoch 00061: val_loss did not improve from 0.00025
# 281/281 [==============================] - 46s 164ms/step - loss: 2.6006e-04 - val_loss: 2.7860e-04
# Epoch 62/128
# 281/281 [==============================] - ETA: 0s - loss: 2.5235e-04
# Epoch 00062: val_loss did not improve from 0.00025
# 281/281 [==============================] - 47s 169ms/step - loss: 2.5235e-04 - val_loss: 2.4775e-04
# Epoch 63/128
# 281/281 [==============================] - ETA: 0s - loss: 2.4751e-04
# Epoch 00063: val_loss did not improve from 0.00025
# 281/281 [==============================] - 50s 179ms/step - loss: 2.4751e-04 - val_loss: 2.4626e-04
# Epoch 64/128
# 281/281 [==============================] - ETA: 0s - loss: 2.5331e-04
# Epoch 00064: val_loss did not improve from 0.00025
# 281/281 [==============================] - 51s 181ms/step - loss: 2.5331e-04 - val_loss: 2.4643e-04
# Epoch 65/128
# 281/281 [==============================] - ETA: 0s - loss: 2.5691e-04
# Epoch 00065: val_loss did not improve from 0.00025
# 281/281 [==============================] - 51s 181ms/step - loss: 2.5691e-04 - val_loss: 2.5278e-04
# Epoch 66/128
# 281/281 [==============================] - ETA: 0s - loss: 2.4598e-04
# Epoch 00066: val_loss improved from 0.00025 to 0.00024, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 47s 166ms/step - loss: 2.4598e-04 - val_loss: 2.4250e-04
# Epoch 67/128
# 281/281 [==============================] - ETA: 0s - loss: 2.4145e-04
# Epoch 00067: val_loss did not improve from 0.00024
# 281/281 [==============================] - 47s 169ms/step - loss: 2.4145e-04 - val_loss: 2.4521e-04
# Epoch 68/128
# 281/281 [==============================] - ETA: 0s - loss: 2.4295e-04
# Epoch 00068: val_loss improved from 0.00024 to 0.00024, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 49s 173ms/step - loss: 2.4295e-04 - val_loss: 2.3920e-04
# Epoch 69/128
# 281/281 [==============================] - ETA: 0s - loss: 2.4252e-04
# Epoch 00069: val_loss improved from 0.00024 to 0.00024, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 49s 173ms/step - loss: 2.4252e-04 - val_loss: 2.3854e-04
# Epoch 70/128
# 281/281 [==============================] - ETA: 0s - loss: 2.5152e-04
# Epoch 00070: val_loss did not improve from 0.00024
# 281/281 [==============================] - 49s 173ms/step - loss: 2.5152e-04 - val_loss: 2.4040e-04
# Epoch 71/128
# 281/281 [==============================] - ETA: 0s - loss: 2.3595e-04
# Epoch 00071: val_loss improved from 0.00024 to 0.00024, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 49s 173ms/step - loss: 2.3595e-04 - val_loss: 2.3684e-04
# Epoch 72/128
# 281/281 [==============================] - ETA: 0s - loss: 2.4309e-04
# Epoch 00072: val_loss did not improve from 0.00024
# 281/281 [==============================] - 48s 172ms/step - loss: 2.4309e-04 - val_loss: 2.6943e-04
# Epoch 73/128
# 281/281 [==============================] - ETA: 0s - loss: 2.4408e-04
# Epoch 00073: val_loss did not improve from 0.00024
# 281/281 [==============================] - 48s 172ms/step - loss: 2.4408e-04 - val_loss: 2.3687e-04
# Epoch 74/128
# 281/281 [==============================] - ETA: 0s - loss: 2.3585e-04
# Epoch 00074: val_loss improved from 0.00024 to 0.00024, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 48s 172ms/step - loss: 2.3585e-04 - val_loss: 2.3520e-04
# Epoch 75/128
# 281/281 [==============================] - ETA: 0s - loss: 2.3890e-04
# Epoch 00075: val_loss did not improve from 0.00024
# 281/281 [==============================] - 48s 172ms/step - loss: 2.3890e-04 - val_loss: 2.4934e-04
# Epoch 76/128
# 281/281 [==============================] - ETA: 0s - loss: 2.3777e-04
# Epoch 00076: val_loss improved from 0.00024 to 0.00023, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 48s 173ms/step - loss: 2.3777e-04 - val_loss: 2.3445e-04
# Epoch 77/128
# 281/281 [==============================] - ETA: 0s - loss: 2.3421e-04
# Epoch 00077: val_loss improved from 0.00023 to 0.00023, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 49s 173ms/step - loss: 2.3421e-04 - val_loss: 2.3282e-04
# Epoch 78/128
# 281/281 [==============================] - ETA: 0s - loss: 2.4106e-04
# Epoch 00078: val_loss improved from 0.00023 to 0.00023, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 48s 172ms/step - loss: 2.4106e-04 - val_loss: 2.3230e-04
# Epoch 79/128
# 281/281 [==============================] - ETA: 0s - loss: 2.3065e-04
# Epoch 00079: val_loss did not improve from 0.00023
# 281/281 [==============================] - 48s 172ms/step - loss: 2.3065e-04 - val_loss: 2.4372e-04
# Epoch 80/128
# 281/281 [==============================] - ETA: 0s - loss: 2.3575e-04
# Epoch 00080: val_loss improved from 0.00023 to 0.00023, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 48s 172ms/step - loss: 2.3575e-04 - val_loss: 2.2946e-04
# Epoch 81/128
# 281/281 [==============================] - ETA: 0s - loss: 2.3682e-04
# Epoch 00081: val_loss did not improve from 0.00023
# 281/281 [==============================] - 48s 172ms/step - loss: 2.3682e-04 - val_loss: 6.2945e-04
# Epoch 82/128
# 281/281 [==============================] - ETA: 0s - loss: 2.4556e-04
# Epoch 00082: val_loss did not improve from 0.00023
# 281/281 [==============================] - 48s 172ms/step - loss: 2.4556e-04 - val_loss: 2.4271e-04
# Epoch 83/128
# 281/281 [==============================] - ETA: 0s - loss: 2.3430e-04
# Epoch 00083: val_loss did not improve from 0.00023
# 281/281 [==============================] - 48s 172ms/step - loss: 2.3430e-04 - val_loss: 2.6729e-04
# Epoch 84/128
# 281/281 [==============================] - ETA: 0s - loss: 2.3239e-04
# Epoch 00084: val_loss did not improve from 0.00023
# 281/281 [==============================] - 48s 172ms/step - loss: 2.3239e-04 - val_loss: 2.3324e-04
# Epoch 85/128
# 281/281 [==============================] - ETA: 0s - loss: 2.2986e-04
# Epoch 00085: val_loss improved from 0.00023 to 0.00023, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 48s 172ms/step - loss: 2.2986e-04 - val_loss: 2.2689e-04
# Epoch 86/128
# 281/281 [==============================] - ETA: 0s - loss: 2.2933e-04
# Epoch 00086: val_loss did not improve from 0.00023
# 281/281 [==============================] - 48s 172ms/step - loss: 2.2933e-04 - val_loss: 2.2842e-04
# Epoch 87/128
# 281/281 [==============================] - ETA: 0s - loss: 2.3147e-04
# Epoch 00087: val_loss did not improve from 0.00023
# 281/281 [==============================] - 48s 172ms/step - loss: 2.3147e-04 - val_loss: 2.4890e-04
# Epoch 88/128
# 281/281 [==============================] - ETA: 0s - loss: 2.3082e-04
# Epoch 00088: val_loss did not improve from 0.00023
# 281/281 [==============================] - 48s 172ms/step - loss: 2.3082e-04 - val_loss: 2.2750e-04
# Epoch 89/128
# 281/281 [==============================] - ETA: 0s - loss: 2.2330e-04
# Epoch 00089: val_loss did not improve from 0.00023
# 281/281 [==============================] - 48s 172ms/step - loss: 2.2330e-04 - val_loss: 2.3629e-04
# Epoch 90/128
# 281/281 [==============================] - ETA: 0s - loss: 2.2724e-04
# Epoch 00090: val_loss did not improve from 0.00023
# 281/281 [==============================] - 48s 172ms/step - loss: 2.2724e-04 - val_loss: 2.3563e-04
# Epoch 91/128
# 281/281 [==============================] - ETA: 0s - loss: 2.2733e-04
# Epoch 00091: val_loss improved from 0.00023 to 0.00022, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 48s 172ms/step - loss: 2.2733e-04 - val_loss: 2.2311e-04
# Epoch 92/128
# 281/281 [==============================] - ETA: 0s - loss: 2.2383e-04
# Epoch 00092: val_loss did not improve from 0.00022
# 281/281 [==============================] - 48s 172ms/step - loss: 2.2383e-04 - val_loss: 2.2802e-04
# Epoch 93/128
# 281/281 [==============================] - ETA: 0s - loss: 2.2590e-04
# Epoch 00093: val_loss did not improve from 0.00022
# 281/281 [==============================] - 48s 172ms/step - loss: 2.2590e-04 - val_loss: 2.2328e-04
# Epoch 94/128
# 281/281 [==============================] - ETA: 0s - loss: 2.2916e-04
# Epoch 00094: val_loss did not improve from 0.00022
# 281/281 [==============================] - 48s 172ms/step - loss: 2.2916e-04 - val_loss: 2.2805e-04
# Epoch 95/128
# 281/281 [==============================] - ETA: 0s - loss: 2.1937e-04
# Epoch 00095: val_loss improved from 0.00022 to 0.00022, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 48s 172ms/step - loss: 2.1937e-04 - val_loss: 2.2116e-04
# Epoch 96/128
# 281/281 [==============================] - ETA: 0s - loss: 2.3856e-04
# Epoch 00096: val_loss did not improve from 0.00022
# 281/281 [==============================] - 48s 172ms/step - loss: 2.3856e-04 - val_loss: 2.2747e-04
# Epoch 97/128
# 281/281 [==============================] - ETA: 0s - loss: 2.2354e-04
# Epoch 00097: val_loss did not improve from 0.00022
# 281/281 [==============================] - 48s 172ms/step - loss: 2.2354e-04 - val_loss: 2.6070e-04
# Epoch 98/128
# 281/281 [==============================] - ETA: 0s - loss: 2.2123e-04
# Epoch 00098: val_loss did not improve from 0.00022
# 281/281 [==============================] - 48s 172ms/step - loss: 2.2123e-04 - val_loss: 2.2382e-04
# Epoch 99/128
# 281/281 [==============================] - ETA: 0s - loss: 2.2997e-04
# Epoch 00099: val_loss improved from 0.00022 to 0.00022, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 46s 165ms/step - loss: 2.2997e-04 - val_loss: 2.2073e-04
# Epoch 100/128
# 281/281 [==============================] - ETA: 0s - loss: 2.2944e-04
# Epoch 00100: val_loss did not improve from 0.00022
# 281/281 [==============================] - 46s 164ms/step - loss: 2.2944e-04 - val_loss: 2.2457e-04
# Epoch 101/128
# 281/281 [==============================] - ETA: 0s - loss: 2.1675e-04
# Epoch 00101: val_loss improved from 0.00022 to 0.00022, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 2.1675e-04 - val_loss: 2.1992e-04
# Epoch 102/128
# 281/281 [==============================] - ETA: 0s - loss: 2.1945e-04
# Epoch 00102: val_loss did not improve from 0.00022
# 281/281 [==============================] - 46s 164ms/step - loss: 2.1945e-04 - val_loss: 2.2041e-04
# Epoch 103/128
# 281/281 [==============================] - ETA: 0s - loss: 2.3133e-04
# Epoch 00103: val_loss did not improve from 0.00022
# 281/281 [==============================] - 46s 164ms/step - loss: 2.3133e-04 - val_loss: 2.2032e-04
# Epoch 104/128
# 281/281 [==============================] - ETA: 0s - loss: 2.2222e-04
# Epoch 00104: val_loss did not improve from 0.00022
# 281/281 [==============================] - 46s 164ms/step - loss: 2.2222e-04 - val_loss: 2.2094e-04
# Epoch 105/128
# 281/281 [==============================] - ETA: 0s - loss: 2.1809e-04
# Epoch 00105: val_loss did not improve from 0.00022
# 281/281 [==============================] - 46s 164ms/step - loss: 2.1809e-04 - val_loss: 2.4263e-04
# Epoch 106/128
# 281/281 [==============================] - ETA: 0s - loss: 2.2274e-04
# Epoch 00106: val_loss improved from 0.00022 to 0.00022, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 2.2274e-04 - val_loss: 2.1707e-04
# Epoch 107/128
# 281/281 [==============================] - ETA: 0s - loss: 2.1734e-04
# Epoch 00107: val_loss did not improve from 0.00022
# 281/281 [==============================] - 46s 164ms/step - loss: 2.1734e-04 - val_loss: 2.1818e-04
# Epoch 108/128
# 281/281 [==============================] - ETA: 0s - loss: 2.2106e-04
# Epoch 00108: val_loss did not improve from 0.00022
# 281/281 [==============================] - 46s 164ms/step - loss: 2.2106e-04 - val_loss: 2.1822e-04
# Epoch 109/128
# 281/281 [==============================] - ETA: 0s - loss: 2.2223e-04
# Epoch 00109: val_loss did not improve from 0.00022
# 281/281 [==============================] - 46s 164ms/step - loss: 2.2223e-04 - val_loss: 2.1870e-04
# Epoch 110/128
# 281/281 [==============================] - ETA: 0s - loss: 2.1278e-04
# Epoch 00110: val_loss improved from 0.00022 to 0.00021, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 2.1278e-04 - val_loss: 2.1476e-04
# Epoch 111/128
# 281/281 [==============================] - ETA: 0s - loss: 2.2276e-04
# Epoch 00111: val_loss did not improve from 0.00021
# 281/281 [==============================] - 46s 164ms/step - loss: 2.2276e-04 - val_loss: 2.1957e-04
# Epoch 112/128
# 281/281 [==============================] - ETA: 0s - loss: 2.1555e-04
# Epoch 00112: val_loss did not improve from 0.00021
# 281/281 [==============================] - 46s 164ms/step - loss: 2.1555e-04 - val_loss: 2.1900e-04
# Epoch 113/128
# 281/281 [==============================] - ETA: 0s - loss: 2.2226e-04
# Epoch 00113: val_loss did not improve from 0.00021
# 281/281 [==============================] - 46s 164ms/step - loss: 2.2226e-04 - val_loss: 2.2210e-04
# Epoch 114/128
# 281/281 [==============================] - ETA: 0s - loss: 2.1533e-04
# Epoch 00114: val_loss did not improve from 0.00021
# 281/281 [==============================] - 46s 164ms/step - loss: 2.1533e-04 - val_loss: 2.2522e-04
# Epoch 115/128
# 281/281 [==============================] - ETA: 0s - loss: 2.1452e-04
# Epoch 00115: val_loss improved from 0.00021 to 0.00021, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 2.1452e-04 - val_loss: 2.1347e-04
# Epoch 116/128
# 281/281 [==============================] - ETA: 0s - loss: 2.1564e-04
# Epoch 00116: val_loss did not improve from 0.00021
# 281/281 [==============================] - 46s 164ms/step - loss: 2.1564e-04 - val_loss: 2.2913e-04
# Epoch 117/128
# 281/281 [==============================] - ETA: 0s - loss: 2.1770e-04
# Epoch 00117: val_loss did not improve from 0.00021
# 281/281 [==============================] - 46s 164ms/step - loss: 2.1770e-04 - val_loss: 2.3219e-04
# Epoch 118/128
# 281/281 [==============================] - ETA: 0s - loss: 2.1111e-04
# Epoch 00118: val_loss improved from 0.00021 to 0.00021, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 2.1111e-04 - val_loss: 2.1198e-04
# Epoch 119/128
# 281/281 [==============================] - ETA: 0s - loss: 2.1298e-04
# Epoch 00119: val_loss did not improve from 0.00021
# 281/281 [==============================] - 46s 164ms/step - loss: 2.1298e-04 - val_loss: 2.3246e-04
# Epoch 120/128
# 281/281 [==============================] - ETA: 0s - loss: 2.3292e-04
# Epoch 00120: val_loss did not improve from 0.00021
# 281/281 [==============================] - 46s 164ms/step - loss: 2.3292e-04 - val_loss: 2.4360e-04
# Epoch 121/128
# 281/281 [==============================] - ETA: 0s - loss: 2.1400e-04
# Epoch 00121: val_loss did not improve from 0.00021
# 281/281 [==============================] - 46s 164ms/step - loss: 2.1400e-04 - val_loss: 2.2622e-04
# Epoch 122/128
# 281/281 [==============================] - ETA: 0s - loss: 2.1999e-04
# Epoch 00122: val_loss did not improve from 0.00021
# 281/281 [==============================] - 49s 174ms/step - loss: 2.1999e-04 - val_loss: 2.1635e-04
# Epoch 123/128
# 281/281 [==============================] - ETA: 0s - loss: 2.1072e-04
# Epoch 00123: val_loss did not improve from 0.00021
# 281/281 [==============================] - 50s 179ms/step - loss: 2.1072e-04 - val_loss: 2.1547e-04
# Epoch 124/128
# 281/281 [==============================] - ETA: 0s - loss: 2.1567e-04
# Epoch 00124: val_loss did not improve from 0.00021
# 281/281 [==============================] - 51s 181ms/step - loss: 2.1567e-04 - val_loss: 2.1987e-04
# Epoch 125/128
# 281/281 [==============================] - ETA: 0s - loss: 2.1447e-04
# Epoch 00125: val_loss did not improve from 0.00021
# 281/281 [==============================] - 51s 181ms/step - loss: 2.1447e-04 - val_loss: 2.1208e-04
# Epoch 126/128
# 281/281 [==============================] - ETA: 0s - loss: 2.1290e-04
# Epoch 00126: val_loss did not improve from 0.00021
# 281/281 [==============================] - 51s 181ms/step - loss: 2.1290e-04 - val_loss: 2.1873e-04
# Epoch 127/128
# 281/281 [==============================] - ETA: 0s - loss: 2.1677e-04
# Epoch 00127: val_loss improved from 0.00021 to 0.00021, saving model to Fish-Gray.hdf5
# 281/281 [==============================] - 51s 181ms/step - loss: 2.1677e-04 - val_loss: 2.1148e-04
# Epoch 128/128
# 281/281 [==============================] - ETA: 0s - loss: 2.1233e-04
# Epoch 00128: val_loss did not improve from 0.00021
# 281/281 [==============================] - 51s 181ms/step - loss: 2.1233e-04 - val_loss: 2.1444e-04

# %% [markdown]
# <h3>模型訓練績效</h3>

# %%
best_iteration = numpy.argmin(score.history['val_loss']) + 1

val_scores = score.history['val_loss'][0:best_iteration]
train_scores = score.history['loss'][0:best_iteration]

fig, ax = plt.subplots(dpi=120)

ax.plot(val_scores, label='val_loss')
ax.plot(train_scores, label='train_loss')

plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# <h3>隨機顯示抽象圖與假圖</h3>

# %%
faint_image_files = glob('%s/F*.jpg' % 'images/faint')

# %%
faint_image_files = glob('%s/F*.jpg' % '/mnt/Treasury/Projects/ComputerVision/Fish-ID/FISH-1/7227/V0')

# %%
my_faint_images = []

for image_file in faint_image_files[:24]:
    _image_file = image_file.replace('\\', '/')

    _fish_image = read_image_file(_image_file)

    my_faint_images.append(numpy.reshape(_fish_image, max_dim))

my_faint_images = numpy.array(my_faint_images)

# %%
my_faint_images = my_faint_images.astype('float32') / 255.
my_faint_images = numpy.reshape(my_faint_images, (my_faint_images.shape[0],) + max_dim)

# %%
my_faint_images.shape
# Out:
# (24, 256, 256, 1)

# %% [markdown]
# <h3>產生假圖</h3>

# %%
encoder = Model(inputs=autoencoder.input, outputs=autoencoder.get_layer("encoded").output)

encoded_imgs = encoder.predict(my_faint_images)
encoded_imgs = encoded_imgs.reshape((len(encoded_imgs), 256, 256, 1))
# Out:
# WARNING:tensorflow:5 out of the last 17 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f68188f7040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
decoded_imgs = autoencoder.predict(my_faint_images)

# %% [markdown]
# <h3>顯示原圖與假圖</h3>

# %%
def find_faint_file_pos(my_image_id=None):
    pos = -1
    
    if my_image_id is None:
        pos = numpy.random.randint(0, my_faint_images.shape[0], 1)[0]
    else:
        for j in range(len(faint_image_files)):
            image_file = faint_image_files[j]
            if my_image_id in image_file:
                pos = j
                break
            
    if pos == -1:
        pos = numpy.random.randint(0, my_faint_images.shape[0], 1)[0]
        
    return pos

# %%
i = find_faint_file_pos()

# %%
fig, (ax0, ax1, ax2) = plt.subplots(dpi=240, ncols=3)

ax0.imshow(my_faint_images[i].reshape(max_dim[0], max_dim[1]), cmap=plt.cm.binary)
ax0.get_xaxis().set_visible(False)
ax0.get_yaxis().set_visible(False)

ax1.imshow(decoded_imgs[i].reshape(max_dim[0], max_dim[1]), cmap=plt.cm.binary)
ax1.get_xaxis().set_visible(False)
ax1.get_yaxis().set_visible(False)

ax2.imshow(encoded_imgs[i].reshape(max_dim[0], max_dim[1]), cmap=plt.cm.binary)
ax2.get_xaxis().set_visible(False)
ax2.get_yaxis().set_visible(False)

plt.tight_layout()
plt.show()
