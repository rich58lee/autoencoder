# %% [markdown]
# <h3>輸入原影像，經過壓縮轉換，再由轉換壓縮碼，還原成類原圖</h3>

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# %%
from glob import glob
import numpy

# %%
import cv2

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator

# %%
import keras
from keras import layers
from keras.models import Model
from keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from pylab import rcParams
from matplotlib import cm

# %% [markdown]
# <h3>環境設置</h3>

# %%
image_path = 'images/objects/train'
max_dim = (256, 256, 3)

kernel = numpy.array([[-1, -1, -1], [-1, 11, -1], [-1, -1, -1]])

alpha = 0.6 # Contrast control (1.0-3.0)
beta = 2 # Brightness control (0-100)

# %%
def read_image_file(my_image_file):
    global max_dim, kernel, alpha, beta
    
    _fish_image = cv2.imread(my_image_file, cv2.COLOR_BGR2RGB)
    _fish_image = cv2.filter2D(_fish_image, -1, kernel)
    _fish_image = cv2.convertScaleAbs(_fish_image.copy(), alpha=alpha, beta=beta)

    _fish_image = cv2.resize(_fish_image.copy(), max_dim[:2])
    
    return _fish_image

# %%
def show_image(my_image):
    global max_dim
    
    _my_image = numpy.reshape(my_image, max_dim)
    
    fig, ax = plt.subplots(dpi=120)
    
    ax.imshow(my_image)
    ax.axis('off')
    
    plt.show()

# %% [markdown]
# <h3>載入魚影像檔</h3>

# %%
datagen = ImageDataGenerator(rotation_range=45,
                             width_shift_range=[0.1, 0.2],
                             height_shift_range=[0.1, 0.2],
                             horizontal_flip=True)

_fish_image = read_image_file('%s/F000079-00001.jpg' % image_path)

fig, ax = plt.subplots(dpi=120, ncols=3)

ax[0].imshow(_fish_image)
ax[0].axis('off')

_fish_img_data = img_to_array(_fish_image)    
_fish_img_data = numpy.expand_dims(_fish_img_data, 0)

it = datagen.flow(_fish_img_data, batch_size=1)

for i in range(1, 3):
    _batch = it.next()
    _generated_image = _batch[0].astype('uint8')
            
    ax[i].imshow(_generated_image, cmap='gray', interpolation='bicubic')
    ax[i].axis('off')
    
plt.tight_layout()
plt.show()

# %%
def load_data(image_path, train_ratio=0.8):
    global max_dim

    datagen = ImageDataGenerator(rotation_range=45,
                                 width_shift_range=[0.1, 0.2],
                                 height_shift_range=[0.1, 0.2],
                                 horizontal_flip=True
    )
    
    image_files = glob('%s/F*.jpg' % image_path)

    my_images = []

    for image_file in image_files:
        _image_file = image_file.replace('\\', '/')
        
        _fish_image = read_image_file(_image_file)
        
        my_images.append(numpy.reshape(_fish_image, max_dim))

        _fish_img_data = img_to_array(_fish_image)    
        _fish_img_data = numpy.expand_dims(_fish_img_data, 0)
        
        it = datagen.flow(_fish_img_data, batch_size=1)

        for i in range(10):
            _batch = it.next()
            _generated_image = _batch[0].astype('uint8')
            
            my_images.append(numpy.reshape(_generated_image, max_dim))

    my_images = numpy.array(my_images)
    numpy.random.shuffle(my_images)
    
    pos = int(my_images.shape[0] * train_ratio)
    return my_images[:pos], my_images[pos:]

# %%
x_train, x_test = load_data(image_path)

# %%
x_train.shape, x_test.shape
# Out:
# ((4488, 256, 256, 3), (1122, 256, 256, 3))

# %%
show_image(x_train[numpy.random.randint(len(x_train))])

# %% [markdown]
# <h3>將 0 ~ 255 值域，轉換為: 0 ~ 1</h3>

# %%
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# %% [markdown]
# <h3>參數設置</h3>
# <p>$$壓縮率: \frac {{256}*{256}={65536}}{64} = 1024$$</p>

# %%
encoding_dim = (32, 32, 64)

# %% [markdown]
# <h3>建立模型</h3>

# %%
input_img = keras.Input(shape=max_dim, name='input')

# %%
x = layers.Conv2D(256, (3, 3), activation='relu', padding='same', name='Conv2D_256')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same', name='MaxPooling2D_256')(x)

# %%
x = layers.Conv2D(128, (3, 3), activation='relu', padding='same', name='Conv2D_128')(x)
x = layers.MaxPooling2D((2, 2), padding='same', name='MaxPooling2D_128')(x)

# %%
x = layers.Conv2D(64, (3, 3), activation='relu', padding='same', name='Conv2D_64')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same', name='encoded')(x)

# %%
x = layers.Conv2DTranspose(64, (3, 3), activation='relu', padding='same', name='Conv2DT_64')(encoded)
x = layers.UpSampling2D((2, 2), name='UpSampling2D_64')(x)

# %%
x = layers.Conv2DTranspose(128, (3, 3), activation='relu', padding='same', name='Conv2DT_128')(x)
x = layers.UpSampling2D((2, 2), name='UpSampling2D_128')(x)

# %%
x = layers.Conv2DTranspose(256, (3, 3), activation='relu', padding='same', name='Conv2DT_256')(x)
x = layers.UpSampling2D((2, 2), name='UpSampling2D_256')(x)

# %%
decoded = layers.Conv2D(max_dim[-1], (3, 3), padding='same', name='output')(x)

# %%
autoencoder = keras.Model(input_img, decoded)

# %%
autoencoder.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 256, 256, 3)]     0
# _________________________________________________________________
# Conv2D_256 (Conv2D)          (None, 256, 256, 256)     7168
# _________________________________________________________________
# MaxPooling2D_256 (MaxPooling (None, 128, 128, 256)     0
# _________________________________________________________________
# Conv2D_128 (Conv2D)          (None, 128, 128, 128)     295040
# _________________________________________________________________
# MaxPooling2D_128 (MaxPooling (None, 64, 64, 128)       0
# _________________________________________________________________
# Conv2D_64 (Conv2D)           (None, 64, 64, 64)        73792
# _________________________________________________________________
# encoded (MaxPooling2D)       (None, 32, 32, 64)        0
# _________________________________________________________________
# Conv2DT_64 (Conv2DTranspose) (None, 32, 32, 64)        36928
# _________________________________________________________________
# UpSampling2D_64 (UpSampling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# Conv2DT_128 (Conv2DTranspose (None, 64, 64, 128)       73856
# _________________________________________________________________
# UpSampling2D_128 (UpSampling (None, 128, 128, 128)     0
# _________________________________________________________________
# Conv2DT_256 (Conv2DTranspose (None, 128, 128, 256)     295168
# _________________________________________________________________
# UpSampling2D_256 (UpSampling (None, 256, 256, 256)     0
# _________________________________________________________________
# output (Conv2D)              (None, 256, 256, 3)       6915
# =================================================================
# Total params: 788,867
# Trainable params: 788,867
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.compile(optimizer='adam', loss='mse')  # binary_crossentropy

# %% [markdown]
# <h3>訓練模型</h3>

# %%
checkpointer = ModelCheckpoint(
    filepath='CNN-C-0-256-128.hdf5', 
    monitor="val_loss", verbose=1, 
    save_best_only=True, mode='auto'
)

earlyStop = EarlyStopping(monitor='val_loss', patience=12)

# %%
num_of_epoch = 512
num_of_batch_size = 8

# %%
score = autoencoder.fit(x_train, x_train,
                        epochs=num_of_epoch,
                        batch_size=num_of_batch_size,
                        shuffle=True,
                        validation_data=(x_test, x_test),
                        callbacks=[checkpointer, earlyStop]
                       )
# Out:
# Epoch 1/1024
#   2/281 [..............................] - ETA: 22s - loss: 0.0635WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0485s vs `on_train_batch_end` time: 0.1150s). Check your callbacks.
# 281/281 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 00001: val_loss improved from inf to 0.00073, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 48s 172ms/step - loss: 0.0031 - val_loss: 7.3500e-04
# Epoch 2/1024
# 281/281 [==============================] - ETA: 0s - loss: 6.9037e-04
# Epoch 00002: val_loss improved from 0.00073 to 0.00062, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 49s 174ms/step - loss: 6.9037e-04 - val_loss: 6.2397e-04
# Epoch 3/1024
# 281/281 [==============================] - ETA: 0s - loss: 6.0164e-04
# Epoch 00003: val_loss improved from 0.00062 to 0.00056, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 50s 178ms/step - loss: 6.0164e-04 - val_loss: 5.5777e-04
# Epoch 4/1024
# 281/281 [==============================] - ETA: 0s - loss: 5.5789e-04
# Epoch 00004: val_loss improved from 0.00056 to 0.00050, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 50s 179ms/step - loss: 5.5789e-04 - val_loss: 4.9991e-04
# Epoch 5/1024
# 281/281 [==============================] - ETA: 0s - loss: 5.5375e-04
# Epoch 00005: val_loss improved from 0.00050 to 0.00049, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 50s 179ms/step - loss: 5.5375e-04 - val_loss: 4.8693e-04
# Epoch 6/1024
# 281/281 [==============================] - ETA: 0s - loss: 5.1614e-04
# Epoch 00006: val_loss improved from 0.00049 to 0.00047, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 50s 179ms/step - loss: 5.1614e-04 - val_loss: 4.7437e-04
# Epoch 7/1024
# 281/281 [==============================] - ETA: 0s - loss: 4.9175e-04
# Epoch 00007: val_loss improved from 0.00047 to 0.00044, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 50s 179ms/step - loss: 4.9175e-04 - val_loss: 4.4284e-04
# Epoch 8/1024
# 281/281 [==============================] - ETA: 0s - loss: 4.8216e-04
# Epoch 00008: val_loss improved from 0.00044 to 0.00043, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 50s 179ms/step - loss: 4.8216e-04 - val_loss: 4.3475e-04
# Epoch 9/1024
# 281/281 [==============================] - ETA: 0s - loss: 4.9010e-04
# Epoch 00009: val_loss did not improve from 0.00043
# 281/281 [==============================] - 50s 179ms/step - loss: 4.9010e-04 - val_loss: 4.5170e-04
# Epoch 10/1024
# 281/281 [==============================] - ETA: 0s - loss: 5.2359e-04
# Epoch 00010: val_loss improved from 0.00043 to 0.00042, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 50s 179ms/step - loss: 5.2359e-04 - val_loss: 4.1664e-04
# Epoch 11/1024
# 281/281 [==============================] - ETA: 0s - loss: 4.1366e-04
# Epoch 00011: val_loss did not improve from 0.00042
# 281/281 [==============================] - 50s 179ms/step - loss: 4.1366e-04 - val_loss: 6.1380e-04
# Epoch 12/1024
# 281/281 [==============================] - ETA: 0s - loss: 4.3749e-04
# Epoch 00012: val_loss did not improve from 0.00042
# 281/281 [==============================] - 50s 179ms/step - loss: 4.3749e-04 - val_loss: 4.2327e-04
# Epoch 13/1024
# 281/281 [==============================] - ETA: 0s - loss: 4.2196e-04
# Epoch 00013: val_loss did not improve from 0.00042
# 281/281 [==============================] - 50s 179ms/step - loss: 4.2196e-04 - val_loss: 5.7567e-04
# Epoch 14/1024
# 281/281 [==============================] - ETA: 0s - loss: 4.2415e-04
# Epoch 00014: val_loss did not improve from 0.00042
# 281/281 [==============================] - 50s 179ms/step - loss: 4.2415e-04 - val_loss: 4.5247e-04
# Epoch 15/1024
# 281/281 [==============================] - ETA: 0s - loss: 4.5149e-04
# Epoch 00015: val_loss improved from 0.00042 to 0.00041, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 50s 179ms/step - loss: 4.5149e-04 - val_loss: 4.1338e-04
# Epoch 16/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.9148e-04
# Epoch 00016: val_loss improved from 0.00041 to 0.00038, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 50s 179ms/step - loss: 3.9148e-04 - val_loss: 3.8481e-04
# Epoch 17/1024
# 281/281 [==============================] - ETA: 0s - loss: 4.1545e-04
# Epoch 00017: val_loss did not improve from 0.00038
# 281/281 [==============================] - 50s 179ms/step - loss: 4.1545e-04 - val_loss: 3.9978e-04
# Epoch 18/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.8380e-04
# Epoch 00018: val_loss improved from 0.00038 to 0.00037, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 50s 179ms/step - loss: 3.8380e-04 - val_loss: 3.6956e-04
# Epoch 19/1024
# 281/281 [==============================] - ETA: 0s - loss: 4.8684e-04
# Epoch 00019: val_loss did not improve from 0.00037
# 281/281 [==============================] - 50s 179ms/step - loss: 4.8684e-04 - val_loss: 3.7071e-04
# Epoch 20/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.6768e-04
# Epoch 00020: val_loss improved from 0.00037 to 0.00037, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 50s 179ms/step - loss: 3.6768e-04 - val_loss: 3.6941e-04
# Epoch 21/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.7921e-04
# Epoch 00021: val_loss improved from 0.00037 to 0.00037, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 50s 179ms/step - loss: 3.7921e-04 - val_loss: 3.6722e-04
# Epoch 22/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.7453e-04
# Epoch 00022: val_loss improved from 0.00037 to 0.00036, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 50s 179ms/step - loss: 3.7453e-04 - val_loss: 3.6110e-04
# Epoch 23/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.7767e-04
# Epoch 00023: val_loss improved from 0.00036 to 0.00035, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 50s 179ms/step - loss: 3.7767e-04 - val_loss: 3.5193e-04
# Epoch 24/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.8048e-04
# Epoch 00024: val_loss did not improve from 0.00035
# 281/281 [==============================] - 50s 179ms/step - loss: 3.8048e-04 - val_loss: 3.7118e-04
# Epoch 25/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.6829e-04
# Epoch 00025: val_loss did not improve from 0.00035
# 281/281 [==============================] - 50s 179ms/step - loss: 3.6829e-04 - val_loss: 5.2359e-04
# Epoch 26/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.6668e-04
# Epoch 00026: val_loss improved from 0.00035 to 0.00035, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 50s 179ms/step - loss: 3.6668e-04 - val_loss: 3.4705e-04
# Epoch 27/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.5369e-04
# Epoch 00027: val_loss did not improve from 0.00035
# 281/281 [==============================] - 50s 178ms/step - loss: 3.5369e-04 - val_loss: 3.7778e-04
# Epoch 28/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.5742e-04
# Epoch 00028: val_loss did not improve from 0.00035
# 281/281 [==============================] - 50s 179ms/step - loss: 3.5742e-04 - val_loss: 3.7322e-04
# Epoch 29/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.4576e-04
# Epoch 00029: val_loss did not improve from 0.00035
# 281/281 [==============================] - 50s 178ms/step - loss: 3.4576e-04 - val_loss: 4.3416e-04
# Epoch 30/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.4874e-04
# Epoch 00030: val_loss did not improve from 0.00035
# 281/281 [==============================] - 50s 178ms/step - loss: 3.4874e-04 - val_loss: 3.8903e-04
# Epoch 31/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.4967e-04
# Epoch 00031: val_loss improved from 0.00035 to 0.00034, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 50s 179ms/step - loss: 3.4967e-04 - val_loss: 3.3539e-04
# Epoch 32/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.3708e-04
# Epoch 00032: val_loss did not improve from 0.00034
# 281/281 [==============================] - 46s 164ms/step - loss: 3.3708e-04 - val_loss: 3.3646e-04
# Epoch 33/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.3884e-04
# Epoch 00033: val_loss did not improve from 0.00034
# 281/281 [==============================] - 46s 164ms/step - loss: 3.3884e-04 - val_loss: 3.5626e-04
# Epoch 34/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.4240e-04
# Epoch 00034: val_loss improved from 0.00034 to 0.00032, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 3.4240e-04 - val_loss: 3.1603e-04
# Epoch 35/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.4383e-04
# Epoch 00035: val_loss did not improve from 0.00032
# 281/281 [==============================] - 46s 164ms/step - loss: 3.4383e-04 - val_loss: 3.1830e-04
# Epoch 36/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.4002e-04
# Epoch 00036: val_loss improved from 0.00032 to 0.00032, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 3.4002e-04 - val_loss: 3.1565e-04
# Epoch 37/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.1847e-04
# Epoch 00037: val_loss improved from 0.00032 to 0.00031, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 3.1847e-04 - val_loss: 3.1191e-04
# Epoch 38/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.4538e-04
# Epoch 00038: val_loss did not improve from 0.00031
# 281/281 [==============================] - 46s 164ms/step - loss: 3.4538e-04 - val_loss: 5.8890e-04
# Epoch 39/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.1674e-04
# Epoch 00039: val_loss did not improve from 0.00031
# 281/281 [==============================] - 46s 164ms/step - loss: 3.1674e-04 - val_loss: 4.0692e-04
# Epoch 40/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.2665e-04
# Epoch 00040: val_loss did not improve from 0.00031
# 281/281 [==============================] - 46s 164ms/step - loss: 3.2665e-04 - val_loss: 3.3701e-04
# Epoch 41/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.1756e-04
# Epoch 00041: val_loss did not improve from 0.00031
# 281/281 [==============================] - 46s 164ms/step - loss: 3.1756e-04 - val_loss: 3.8526e-04
# Epoch 42/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.1962e-04
# Epoch 00042: val_loss improved from 0.00031 to 0.00031, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 3.1962e-04 - val_loss: 3.0582e-04
# Epoch 43/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.0886e-04
# Epoch 00043: val_loss did not improve from 0.00031
# 281/281 [==============================] - 46s 164ms/step - loss: 3.0886e-04 - val_loss: 3.6921e-04
# Epoch 44/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.1963e-04
# Epoch 00044: val_loss did not improve from 0.00031
# 281/281 [==============================] - 46s 164ms/step - loss: 3.1963e-04 - val_loss: 3.7702e-04
# Epoch 45/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.0539e-04
# Epoch 00045: val_loss did not improve from 0.00031
# 281/281 [==============================] - 46s 164ms/step - loss: 3.0539e-04 - val_loss: 3.0920e-04
# Epoch 46/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.1327e-04
# Epoch 00046: val_loss improved from 0.00031 to 0.00030, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 3.1327e-04 - val_loss: 2.9859e-04
# Epoch 47/1024
# 281/281 [==============================] - ETA: 0s - loss: 4.4846e-04
# Epoch 00047: val_loss did not improve from 0.00030
# 281/281 [==============================] - 46s 164ms/step - loss: 4.4846e-04 - val_loss: 4.1113e-04
# Epoch 48/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.5476e-04
# Epoch 00048: val_loss did not improve from 0.00030
# 281/281 [==============================] - 46s 164ms/step - loss: 3.5476e-04 - val_loss: 3.2570e-04
# Epoch 49/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.3865e-04
# Epoch 00049: val_loss did not improve from 0.00030
# 281/281 [==============================] - 46s 164ms/step - loss: 3.3865e-04 - val_loss: 3.4665e-04
# Epoch 50/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.2274e-04
# Epoch 00050: val_loss did not improve from 0.00030
# 281/281 [==============================] - 46s 164ms/step - loss: 3.2274e-04 - val_loss: 3.1322e-04
# Epoch 51/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.1402e-04
# Epoch 00051: val_loss did not improve from 0.00030
# 281/281 [==============================] - 46s 164ms/step - loss: 3.1402e-04 - val_loss: 4.4268e-04
# Epoch 52/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.1525e-04
# Epoch 00052: val_loss did not improve from 0.00030
# 281/281 [==============================] - 46s 164ms/step - loss: 3.1525e-04 - val_loss: 3.1298e-04
# Epoch 53/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.1379e-04
# Epoch 00053: val_loss did not improve from 0.00030
# 281/281 [==============================] - 46s 164ms/step - loss: 3.1379e-04 - val_loss: 3.2438e-04
# Epoch 54/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.1379e-04
# Epoch 00054: val_loss did not improve from 0.00030
# 281/281 [==============================] - 46s 164ms/step - loss: 3.1379e-04 - val_loss: 3.0309e-04
# Epoch 55/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.0887e-04
# Epoch 00055: val_loss improved from 0.00030 to 0.00029, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 3.0887e-04 - val_loss: 2.9456e-04
# Epoch 56/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.0459e-04
# Epoch 00056: val_loss did not improve from 0.00029
# 281/281 [==============================] - 46s 164ms/step - loss: 3.0459e-04 - val_loss: 2.9921e-04
# Epoch 57/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.0428e-04
# Epoch 00057: val_loss did not improve from 0.00029
# 281/281 [==============================] - 46s 164ms/step - loss: 3.0428e-04 - val_loss: 3.2227e-04
# Epoch 58/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.2698e-04
# Epoch 00058: val_loss did not improve from 0.00029
# 281/281 [==============================] - 46s 164ms/step - loss: 3.2698e-04 - val_loss: 4.4891e-04
# Epoch 59/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.0737e-04
# Epoch 00059: val_loss improved from 0.00029 to 0.00029, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 3.0737e-04 - val_loss: 2.9403e-04
# Epoch 60/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.9605e-04
# Epoch 00060: val_loss improved from 0.00029 to 0.00029, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 2.9605e-04 - val_loss: 2.9308e-04
# Epoch 61/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.9929e-04
# Epoch 00061: val_loss improved from 0.00029 to 0.00029, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 2.9929e-04 - val_loss: 2.8761e-04
# Epoch 62/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.9470e-04
# Epoch 00062: val_loss improved from 0.00029 to 0.00029, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 2.9470e-04 - val_loss: 2.8515e-04
# Epoch 63/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.9409e-04
# Epoch 00063: val_loss did not improve from 0.00029
# 281/281 [==============================] - 46s 164ms/step - loss: 2.9409e-04 - val_loss: 3.6640e-04
# Epoch 64/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.9224e-04
# Epoch 00064: val_loss did not improve from 0.00029
# 281/281 [==============================] - 46s 164ms/step - loss: 2.9224e-04 - val_loss: 3.0945e-04
# Epoch 65/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.9087e-04
# Epoch 00065: val_loss did not improve from 0.00029
# 281/281 [==============================] - 46s 164ms/step - loss: 2.9087e-04 - val_loss: 3.1110e-04
# Epoch 66/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.9703e-04
# Epoch 00066: val_loss improved from 0.00029 to 0.00028, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 2.9703e-04 - val_loss: 2.8243e-04
# Epoch 67/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.8742e-04
# Epoch 00067: val_loss improved from 0.00028 to 0.00028, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 2.8742e-04 - val_loss: 2.7994e-04
# Epoch 68/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.8735e-04
# Epoch 00068: val_loss did not improve from 0.00028
# 281/281 [==============================] - 46s 164ms/step - loss: 2.8735e-04 - val_loss: 2.8038e-04
# Epoch 69/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.8880e-04
# Epoch 00069: val_loss did not improve from 0.00028
# 281/281 [==============================] - 46s 164ms/step - loss: 2.8880e-04 - val_loss: 2.8737e-04
# Epoch 70/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.9181e-04
# Epoch 00070: val_loss improved from 0.00028 to 0.00028, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 2.9181e-04 - val_loss: 2.7954e-04
# Epoch 71/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.8455e-04
# Epoch 00071: val_loss did not improve from 0.00028
# 281/281 [==============================] - 46s 164ms/step - loss: 2.8455e-04 - val_loss: 2.9054e-04
# Epoch 72/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.8765e-04
# Epoch 00072: val_loss improved from 0.00028 to 0.00028, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 2.8765e-04 - val_loss: 2.7855e-04
# Epoch 73/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.8009e-04
# Epoch 00073: val_loss improved from 0.00028 to 0.00028, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 2.8009e-04 - val_loss: 2.7508e-04
# Epoch 74/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.8608e-04
# Epoch 00074: val_loss did not improve from 0.00028
# 281/281 [==============================] - 46s 164ms/step - loss: 2.8608e-04 - val_loss: 2.7797e-04
# Epoch 75/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.8302e-04
# Epoch 00075: val_loss did not improve from 0.00028
# 281/281 [==============================] - 46s 164ms/step - loss: 2.8302e-04 - val_loss: 3.9381e-04
# Epoch 76/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.8516e-04
# Epoch 00076: val_loss did not improve from 0.00028
# 281/281 [==============================] - 46s 164ms/step - loss: 2.8516e-04 - val_loss: 3.4385e-04
# Epoch 77/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.4233e-04
# Epoch 00077: val_loss did not improve from 0.00028
# 281/281 [==============================] - 46s 164ms/step - loss: 3.4233e-04 - val_loss: 3.0673e-04
# Epoch 78/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.8858e-04
# Epoch 00078: val_loss did not improve from 0.00028
# 281/281 [==============================] - 46s 164ms/step - loss: 2.8858e-04 - val_loss: 2.9181e-04
# Epoch 79/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.8551e-04
# Epoch 00079: val_loss did not improve from 0.00028
# 281/281 [==============================] - 46s 164ms/step - loss: 2.8551e-04 - val_loss: 2.8350e-04
# Epoch 80/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.9406e-04
# Epoch 00080: val_loss did not improve from 0.00028
# 281/281 [==============================] - 46s 164ms/step - loss: 2.9406e-04 - val_loss: 2.7886e-04
# Epoch 81/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.7925e-04
# Epoch 00081: val_loss did not improve from 0.00028
# 281/281 [==============================] - 46s 164ms/step - loss: 2.7925e-04 - val_loss: 2.8162e-04
# Epoch 82/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.7871e-04
# Epoch 00082: val_loss improved from 0.00028 to 0.00027, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 2.7871e-04 - val_loss: 2.7377e-04
# Epoch 83/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.8385e-04
# Epoch 00083: val_loss did not improve from 0.00027
# 281/281 [==============================] - 46s 164ms/step - loss: 2.8385e-04 - val_loss: 2.7530e-04
# Epoch 84/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.8139e-04
# Epoch 00084: val_loss did not improve from 0.00027
# 281/281 [==============================] - 46s 164ms/step - loss: 2.8139e-04 - val_loss: 2.8080e-04
# Epoch 85/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.7871e-04
# Epoch 00085: val_loss did not improve from 0.00027
# 281/281 [==============================] - 46s 164ms/step - loss: 2.7871e-04 - val_loss: 2.7650e-04
# Epoch 86/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.8537e-04
# Epoch 00086: val_loss did not improve from 0.00027
# 281/281 [==============================] - 46s 164ms/step - loss: 2.8537e-04 - val_loss: 2.7740e-04
# Epoch 87/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.8151e-04
# Epoch 00087: val_loss did not improve from 0.00027
# 281/281 [==============================] - 46s 164ms/step - loss: 2.8151e-04 - val_loss: 2.7643e-04
# Epoch 88/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.7248e-04
# Epoch 00088: val_loss did not improve from 0.00027
# 281/281 [==============================] - 46s 164ms/step - loss: 2.7248e-04 - val_loss: 2.8963e-04
# Epoch 89/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.7786e-04
# Epoch 00089: val_loss improved from 0.00027 to 0.00027, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 2.7786e-04 - val_loss: 2.6842e-04
# Epoch 90/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.7319e-04
# Epoch 00090: val_loss did not improve from 0.00027
# 281/281 [==============================] - 46s 164ms/step - loss: 2.7319e-04 - val_loss: 2.8176e-04
# Epoch 91/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.7427e-04
# Epoch 00091: val_loss did not improve from 0.00027
# 281/281 [==============================] - 46s 164ms/step - loss: 2.7427e-04 - val_loss: 2.7837e-04
# Epoch 92/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.0511e-04
# Epoch 00092: val_loss did not improve from 0.00027
# 281/281 [==============================] - 46s 164ms/step - loss: 3.0511e-04 - val_loss: 2.7432e-04
# Epoch 93/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.7086e-04
# Epoch 00093: val_loss did not improve from 0.00027
# 281/281 [==============================] - 46s 164ms/step - loss: 2.7086e-04 - val_loss: 2.7372e-04
# Epoch 94/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.7420e-04
# Epoch 00094: val_loss did not improve from 0.00027
# 281/281 [==============================] - 46s 164ms/step - loss: 2.7420e-04 - val_loss: 2.7401e-04
# Epoch 95/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.7032e-04
# Epoch 00095: val_loss improved from 0.00027 to 0.00027, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 2.7032e-04 - val_loss: 2.6695e-04
# Epoch 96/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.7162e-04
# Epoch 00096: val_loss did not improve from 0.00027
# 281/281 [==============================] - 46s 164ms/step - loss: 2.7162e-04 - val_loss: 2.6974e-04
# Epoch 97/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.7439e-04
# Epoch 00097: val_loss did not improve from 0.00027
# 281/281 [==============================] - 46s 164ms/step - loss: 2.7439e-04 - val_loss: 2.6830e-04
# Epoch 98/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.8028e-04
# Epoch 00098: val_loss improved from 0.00027 to 0.00027, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 2.8028e-04 - val_loss: 2.6640e-04
# Epoch 99/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.6722e-04
# Epoch 00099: val_loss did not improve from 0.00027
# 281/281 [==============================] - 46s 164ms/step - loss: 2.6722e-04 - val_loss: 2.7848e-04
# Epoch 100/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.6794e-04
# Epoch 00100: val_loss did not improve from 0.00027
# 281/281 [==============================] - 46s 164ms/step - loss: 2.6794e-04 - val_loss: 2.8906e-04
# Epoch 101/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.7002e-04
# Epoch 00101: val_loss improved from 0.00027 to 0.00027, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 2.7002e-04 - val_loss: 2.6617e-04
# Epoch 102/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.6679e-04
# Epoch 00102: val_loss did not improve from 0.00027
# 281/281 [==============================] - 46s 164ms/step - loss: 2.6679e-04 - val_loss: 2.7186e-04
# Epoch 103/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.6834e-04
# Epoch 00103: val_loss improved from 0.00027 to 0.00026, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 2.6834e-04 - val_loss: 2.6303e-04
# Epoch 104/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.6602e-04
# Epoch 00104: val_loss did not improve from 0.00026
# 281/281 [==============================] - 46s 164ms/step - loss: 2.6602e-04 - val_loss: 2.6731e-04
# Epoch 105/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.6856e-04
# Epoch 00105: val_loss did not improve from 0.00026
# 281/281 [==============================] - 46s 164ms/step - loss: 2.6856e-04 - val_loss: 2.8082e-04
# Epoch 106/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.6607e-04
# Epoch 00106: val_loss did not improve from 0.00026
# 281/281 [==============================] - 46s 164ms/step - loss: 2.6607e-04 - val_loss: 2.6405e-04
# Epoch 107/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.7475e-04
# Epoch 00107: val_loss improved from 0.00026 to 0.00026, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 2.7475e-04 - val_loss: 2.6223e-04
# Epoch 108/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.6251e-04
# Epoch 00108: val_loss improved from 0.00026 to 0.00026, saving model to Fish-Color.hdf5
# 281/281 [==============================] - 46s 164ms/step - loss: 2.6251e-04 - val_loss: 2.6079e-04
# Epoch 109/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.6961e-04
# Epoch 00109: val_loss did not improve from 0.00026
# 281/281 [==============================] - 46s 164ms/step - loss: 2.6961e-04 - val_loss: 2.6228e-04
# Epoch 110/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.6029e-04
# Epoch 00110: val_loss did not improve from 0.00026
# 281/281 [==============================] - 46s 164ms/step - loss: 2.6029e-04 - val_loss: 2.7192e-04
# Epoch 111/1024
# 281/281 [==============================] - ETA: 0s - loss: 2.6317e-04
# Epoch 00111: val_loss did not improve from 0.00026
# 281/281 [==============================] - 46s 164ms/step - loss: 2.6317e-04 - val_loss: 2.6297e-04
# Epoch 112/1024
# 281/281 [==============================] - ETA: 0s - loss: 5.3923e-04
# Epoch 00112: val_loss did not improve from 0.00026
# 281/281 [==============================] - 46s 164ms/step - loss: 5.3923e-04 - val_loss: 4.7943e-04
# Epoch 113/1024
# 281/281 [==============================] - ETA: 0s - loss: 4.1209e-04
# Epoch 00113: val_loss did not improve from 0.00026
# 281/281 [==============================] - 46s 164ms/step - loss: 4.1209e-04 - val_loss: 3.8567e-04
# Epoch 114/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.6482e-04
# Epoch 00114: val_loss did not improve from 0.00026
# 281/281 [==============================] - 46s 163ms/step - loss: 3.6482e-04 - val_loss: 3.5262e-04
# Epoch 115/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.4449e-04
# Epoch 00115: val_loss did not improve from 0.00026
# 281/281 [==============================] - 46s 164ms/step - loss: 3.4449e-04 - val_loss: 3.3916e-04
# Epoch 116/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.3503e-04
# Epoch 00116: val_loss did not improve from 0.00026
# 281/281 [==============================] - 46s 164ms/step - loss: 3.3503e-04 - val_loss: 3.3507e-04
# Epoch 117/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.2763e-04
# Epoch 00117: val_loss did not improve from 0.00026
# 281/281 [==============================] - 46s 164ms/step - loss: 3.2763e-04 - val_loss: 3.4651e-04
# Epoch 118/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.2245e-04
# Epoch 00118: val_loss did not improve from 0.00026
# 281/281 [==============================] - 46s 164ms/step - loss: 3.2245e-04 - val_loss: 3.3401e-04
# Epoch 119/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.1510e-04
# Epoch 00119: val_loss did not improve from 0.00026
# 281/281 [==============================] - 46s 164ms/step - loss: 3.1510e-04 - val_loss: 3.1086e-04
# Epoch 120/1024
# 281/281 [==============================] - ETA: 0s - loss: 3.1516e-04
# Epoch 00120: val_loss did not improve from 0.00026
# 281/281 [==============================] - 46s 164ms/step - loss: 3.1516e-04 - val_loss: 3.0696e-04

# %% [markdown]
# <h3>模型訓練績效</h3>

# %%
best_iteration = numpy.argmin(score.history['val_loss']) + 1

val_scores = score.history['val_loss'][0:best_iteration]
train_scores = score.history['loss'][0:best_iteration]

fig, ax = plt.subplots(dpi=120)

ax.plot(val_scores, label='val_loss')
ax.plot(train_scores, label='train_loss')

plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# <h3>隨機顯示抽象圖與假圖</h3>

# %%
faint_image_files = glob('%s/F*.jpg' % '/mnt/Treasury/Projects/ComputerVision/Fish-ID/FISH-1/7227/V0')

# %%
my_faint_images = []

for image_file in faint_image_files[:24]:
    _image_file = image_file.replace('\\', '/')

    _fish_image = read_image_file(_image_file)

    my_faint_images.append(numpy.reshape(_fish_image, max_dim))

my_faint_images = numpy.array(my_faint_images)

# %%
my_faint_images = my_faint_images.astype('float32') / 255.
my_faint_images = numpy.reshape(my_faint_images, (my_faint_images.shape[0],) + max_dim)

# %%
my_faint_images.shape
# Out:
# (24, 256, 256, 3)

# %% [markdown]
# <h3>產生假圖</h3>

# %%
encoder = Model(inputs=autoencoder.input, outputs=autoencoder.get_layer("encoded").output)

encoded_imgs = encoder.predict(my_faint_images)
encoded_imgs = encoded_imgs.reshape((len(encoded_imgs), max_dim[0], max_dim[1], 1))

# %%
decoded_imgs = autoencoder.predict(my_faint_images)

# %% [markdown]
# <h3>顯示原圖與假圖</h3>

# %%
def find_faint_file_pos(my_image_id=None):
    pos = -1
    
    if my_image_id is None:
        pos = numpy.random.randint(0, my_faint_images.shape[0], 1)[0]
    else:
        for j in range(len(faint_image_files)):
            image_file = faint_image_files[j]
            if my_image_id in image_file:
                pos = j
                break
            
    if pos == -1:
        pos = numpy.random.randint(0, my_faint_images.shape[0], 1)[0]
        
    return pos

# %%
i = find_faint_file_pos()

# %%
fig, (ax0, ax1, ax2) = plt.subplots(dpi=240, ncols=3)

ax0.imshow(my_faint_images[i].reshape(max_dim[0], max_dim[1], max_dim[2]))
ax0.get_xaxis().set_visible(False)
ax0.get_yaxis().set_visible(False)

ax1.imshow(decoded_imgs[i].reshape(max_dim[0], max_dim[1], max_dim[2]))
ax1.get_xaxis().set_visible(False)
ax1.get_yaxis().set_visible(False)

ax2.imshow(encoded_imgs[i].reshape(max_dim[0], max_dim[1]), cmap=plt.cm.binary)
ax2.get_xaxis().set_visible(False)
ax2.get_yaxis().set_visible(False)

plt.tight_layout()
plt.show()
