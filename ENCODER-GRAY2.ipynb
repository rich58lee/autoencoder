# %% [markdown]
# <h3>輸入原影像，經過壓縮轉換，再由轉換壓縮碼，還原成類原圖</h3>

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# %%
from glob import glob
import numpy

# %%
import cv2

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator

# %%
import keras
from keras import layers
from keras.models import Model
from keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from pylab import rcParams
from matplotlib import cm

# %% [markdown]
# <h3>環境設置</h3>

# %%
image_path = '/mnt/Treasury/Projects/ComputerVision/Fish-ID/FISH-1/7227/V0'
max_dim = (256, 256, 1)

kernel = numpy.array([[-1, -1, -1], [-1, 11, -1], [-1, -1, -1]])

alpha = 0.6 # Contrast control (1.0-3.0)
beta = 2 # Brightness control (0-100)

# %%
def read_image_file(my_image_file):
    global max_dim, kernel, alpha, beta
    
    _fish_image = cv2.imread(my_image_file, 0)
    _fish_image = cv2.filter2D(_fish_image, -1, kernel)
    _fish_image = cv2.convertScaleAbs(_fish_image.copy(), alpha=alpha, beta=beta)

    _fish_image = cv2.resize(_fish_image.copy(), max_dim[:2])
    
    return _fish_image

# %%
def show_image(my_image):
    global max_dim
    
    _my_image = numpy.reshape(my_image, max_dim)
    
    fig, ax = plt.subplots(dpi=120)
    
    ax.imshow(my_image, cmap='gray', interpolation='bicubic')
    ax.axis('off')
    
    plt.show()

# %% [markdown]
# <h3>載入魚影像檔</h3>

# %%
datagen = ImageDataGenerator(featurewise_center=True,
                             featurewise_std_normalization=True,
                             rotation_range=45,
                             width_shift_range=[0.1, 0.2],
                             height_shift_range=[0.1, 0.2],
                             horizontal_flip=True)

_fish_image = read_image_file('%s/F000457.jpg' % image_path)

fig, ax = plt.subplots(dpi=120, ncols=3)

ax[0].imshow(_fish_image, cmap='gray', interpolation='bicubic')
ax[0].axis('off')

_fish_img_data = img_to_array(_fish_image)    
_fish_img_data = numpy.expand_dims(_fish_img_data, 0)

it = datagen.flow(_fish_img_data, batch_size=1)

for i in range(1, 3):
    _batch = it.next()
    _generated_image = _batch[0].astype('uint8')
            
    ax[i].imshow(_generated_image, cmap='gray', interpolation='bicubic')
    ax[i].axis('off')
    
plt.tight_layout()
plt.show()
# Out:
# /home/solarwind/anaconda3/envs/tensorflow/lib/python3.8/site-packages/keras_preprocessing/image/image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /home/solarwind/anaconda3/envs/tensorflow/lib/python3.8/site-packages/keras_preprocessing/image/image_data_generator.py:728: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '

# %%
def load_data(image_path, train_ratio=0.8):
    global max_dim

    datagen = ImageDataGenerator(featurewise_center=True,
                                 featurewise_std_normalization=True,
                                 rotation_range=45,
                                 width_shift_range=[0.1, 0.2],
                                 height_shift_range=[0.1, 0.2],
                                 horizontal_flip=True
    )
    
    image_files = glob('%s/F*.jpg' % image_path)

    my_images = []

    for image_file in image_files:
        _image_file = image_file.replace('\\', '/')
        
        _fish_image = read_image_file(_image_file)
        
        my_images.append(numpy.reshape(_fish_image, max_dim))

        _fish_img_data = img_to_array(_fish_image)    
        _fish_img_data = numpy.expand_dims(_fish_img_data, 0)
        
        it = datagen.flow(_fish_img_data, batch_size=1)

        for i in range(10):
            _batch = it.next()
            _generated_image = _batch[0].astype('uint8')
            
            my_images.append(numpy.reshape(_generated_image, max_dim))

    my_images = numpy.array(my_images)
    numpy.random.shuffle(my_images)
    
    pos = int(my_images.shape[0] * train_ratio)
    return my_images[:pos], my_images[pos:]

# %%
x_train, x_test = load_data(image_path)

# %%
x_train.shape, x_test.shape
# Out:
# ((5614, 256, 256, 1), (1404, 256, 256, 1))

# %%
show_image(x_train[numpy.random.randint(len(x_train))])

# %% [markdown]
# <h3>將 0 ~ 255 值域，轉換為: 0 ~ 1</h3>

# %%
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# %% [markdown]
# <h3>參數設置</h3>
# <p>$$壓縮率: \frac {{256}*{256}={65536}}{64} = 1024$$</p>

# %%
encoding_dim = (32, 32, 64)

# %% [markdown]
# <h3>建立模型</h3>

# %%
input_img = keras.Input(shape=max_dim, name='input')

# %%
x = layers.Conv2D(256, (3, 3), activation='relu', padding='same', name='Conv2D_256')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same', name='MaxPooling2D_256')(x)

# %%
x = layers.Conv2D(128, (3, 3), activation='relu', padding='same', name='Conv2D_128')(x)
x = layers.MaxPooling2D((2, 2), padding='same', name='MaxPooling2D_128')(x)

# %%
x = layers.Conv2D(64, (3, 3), activation='relu', padding='same', name='Conv2D_64')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same', name='encoded')(x)

# %%
x = layers.Conv2DTranspose(64, (3, 3), activation='relu', padding='same', name='Conv2DT_64')(encoded)
x = layers.UpSampling2D((2, 2), name='UpSampling2D_64')(x)

# %%
x = layers.Conv2DTranspose(128, (3, 3), activation='relu', padding='same', name='Conv2DT_128')(x)
x = layers.UpSampling2D((2, 2), name='UpSampling2D_128')(x)

# %%
x = layers.Conv2DTranspose(256, (3, 3), activation='relu', padding='same', name='Conv2DT_256')(x)
x = layers.UpSampling2D((2, 2), name='UpSampling2D_256')(x)

# %%
decoded = layers.Conv2D(1, (3, 3), padding='same', name='output')(x)

# %%
autoencoder = keras.Model(input_img, decoded)

# %%
autoencoder.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 256, 256, 1)]     0
# _________________________________________________________________
# Conv2D_256 (Conv2D)          (None, 256, 256, 256)     2560
# _________________________________________________________________
# MaxPooling2D_256 (MaxPooling (None, 128, 128, 256)     0
# _________________________________________________________________
# Conv2D_128 (Conv2D)          (None, 128, 128, 128)     295040
# _________________________________________________________________
# MaxPooling2D_128 (MaxPooling (None, 64, 64, 128)       0
# _________________________________________________________________
# Conv2D_64 (Conv2D)           (None, 64, 64, 64)        73792
# _________________________________________________________________
# encoded (MaxPooling2D)       (None, 32, 32, 64)        0
# _________________________________________________________________
# Conv2DT_64 (Conv2DTranspose) (None, 32, 32, 64)        36928
# _________________________________________________________________
# UpSampling2D_64 (UpSampling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# Conv2DT_128 (Conv2DTranspose (None, 64, 64, 128)       73856
# _________________________________________________________________
# UpSampling2D_128 (UpSampling (None, 128, 128, 128)     0
# _________________________________________________________________
# Conv2DT_256 (Conv2DTranspose (None, 128, 128, 256)     295168
# _________________________________________________________________
# UpSampling2D_256 (UpSampling (None, 256, 256, 256)     0
# _________________________________________________________________
# output (Conv2D)              (None, 256, 256, 1)       2305
# =================================================================
# Total params: 779,649
# Trainable params: 779,649
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.compile(optimizer='adam', loss='mse')  # binary_crossentropy

# %% [markdown]
# <h3>訓練模型</h3>

# %%
checkpointer = ModelCheckpoint(
    filepath='Fish-Gray2.hdf5', 
    monitor="val_loss", verbose=1, 
    save_best_only=True, mode='auto'
)

earlyStop = EarlyStopping(monitor='val_loss', patience=12)

# %%
num_of_epoch = 1024
num_of_batch_size = 16

# %%
score = autoencoder.fit(x_train, x_train,
                        epochs=num_of_epoch,
                        batch_size=num_of_batch_size,
                        shuffle=True,
                        validation_data=(x_test, x_test),
                        callbacks=[checkpointer, earlyStop]
                       )
# Out:
# Epoch 1/1024
#   2/351 [..............................] - ETA: 29s - loss: 0.0448WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0576s vs `on_train_batch_end` time: 0.1085s). Check your callbacks.
# 351/351 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 00001: val_loss improved from inf to 0.00153, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 61s 173ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 2/1024
# 351/351 [==============================] - ETA: 0s - loss: 7.9843e-04
# Epoch 00002: val_loss improved from 0.00153 to 0.00068, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 62s 177ms/step - loss: 7.9843e-04 - val_loss: 6.8213e-04
# Epoch 3/1024
# 351/351 [==============================] - ETA: 0s - loss: 6.7396e-04
# Epoch 00003: val_loss improved from 0.00068 to 0.00067, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 63s 180ms/step - loss: 6.7396e-04 - val_loss: 6.6593e-04
# Epoch 4/1024
# 351/351 [==============================] - ETA: 0s - loss: 6.2434e-04
# Epoch 00004: val_loss improved from 0.00067 to 0.00063, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 63s 180ms/step - loss: 6.2434e-04 - val_loss: 6.3269e-04
# Epoch 5/1024
# 351/351 [==============================] - ETA: 0s - loss: 6.5897e-04
# Epoch 00005: val_loss did not improve from 0.00063
# 351/351 [==============================] - 63s 180ms/step - loss: 6.5897e-04 - val_loss: 6.8301e-04
# Epoch 6/1024
# 351/351 [==============================] - ETA: 0s - loss: 5.5041e-04
# Epoch 00006: val_loss improved from 0.00063 to 0.00061, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 63s 180ms/step - loss: 5.5041e-04 - val_loss: 6.1470e-04
# Epoch 7/1024
# 351/351 [==============================] - ETA: 0s - loss: 5.3704e-04
# Epoch 00007: val_loss improved from 0.00061 to 0.00051, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 63s 180ms/step - loss: 5.3704e-04 - val_loss: 5.0638e-04
# Epoch 8/1024
# 351/351 [==============================] - ETA: 0s - loss: 6.1186e-04
# Epoch 00008: val_loss did not improve from 0.00051
# 351/351 [==============================] - 63s 180ms/step - loss: 6.1186e-04 - val_loss: 5.3863e-04
# Epoch 9/1024
# 351/351 [==============================] - ETA: 0s - loss: 5.3312e-04
# Epoch 00009: val_loss improved from 0.00051 to 0.00049, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 63s 180ms/step - loss: 5.3312e-04 - val_loss: 4.9078e-04
# Epoch 10/1024
# 351/351 [==============================] - ETA: 0s - loss: 4.9978e-04
# Epoch 00010: val_loss improved from 0.00049 to 0.00048, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 63s 181ms/step - loss: 4.9978e-04 - val_loss: 4.7841e-04
# Epoch 11/1024
# 351/351 [==============================] - ETA: 0s - loss: 4.8995e-04
# Epoch 00011: val_loss did not improve from 0.00048
# 351/351 [==============================] - 63s 180ms/step - loss: 4.8995e-04 - val_loss: 5.4234e-04
# Epoch 12/1024
# 351/351 [==============================] - ETA: 0s - loss: 4.8793e-04
# Epoch 00012: val_loss did not improve from 0.00048
# 351/351 [==============================] - 63s 180ms/step - loss: 4.8793e-04 - val_loss: 4.9156e-04
# Epoch 13/1024
# 351/351 [==============================] - ETA: 0s - loss: 4.8187e-04
# Epoch 00013: val_loss improved from 0.00048 to 0.00045, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 63s 180ms/step - loss: 4.8187e-04 - val_loss: 4.5259e-04
# Epoch 14/1024
# 351/351 [==============================] - ETA: 0s - loss: 4.7503e-04
# Epoch 00014: val_loss improved from 0.00045 to 0.00044, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 63s 180ms/step - loss: 4.7503e-04 - val_loss: 4.4154e-04
# Epoch 15/1024
# 351/351 [==============================] - ETA: 0s - loss: 4.4862e-04
# Epoch 00015: val_loss improved from 0.00044 to 0.00043, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 63s 181ms/step - loss: 4.4862e-04 - val_loss: 4.3171e-04
# Epoch 16/1024
# 351/351 [==============================] - ETA: 0s - loss: 4.3743e-04
# Epoch 00016: val_loss improved from 0.00043 to 0.00043, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 63s 180ms/step - loss: 4.3743e-04 - val_loss: 4.2769e-04
# Epoch 17/1024
# 351/351 [==============================] - ETA: 0s - loss: 4.4652e-04
# Epoch 00017: val_loss did not improve from 0.00043
# 351/351 [==============================] - 63s 180ms/step - loss: 4.4652e-04 - val_loss: 4.5239e-04
# Epoch 18/1024
# 351/351 [==============================] - ETA: 0s - loss: 4.5272e-04
# Epoch 00018: val_loss did not improve from 0.00043
# 351/351 [==============================] - 63s 180ms/step - loss: 4.5272e-04 - val_loss: 4.2976e-04
# Epoch 19/1024
# 351/351 [==============================] - ETA: 0s - loss: 4.2184e-04
# Epoch 00019: val_loss improved from 0.00043 to 0.00042, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 63s 180ms/step - loss: 4.2184e-04 - val_loss: 4.1940e-04
# Epoch 20/1024
# 351/351 [==============================] - ETA: 0s - loss: 4.1838e-04
# Epoch 00020: val_loss improved from 0.00042 to 0.00040, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 63s 180ms/step - loss: 4.1838e-04 - val_loss: 4.0039e-04
# Epoch 21/1024
# 351/351 [==============================] - ETA: 0s - loss: 4.1384e-04
# Epoch 00021: val_loss did not improve from 0.00040
# 351/351 [==============================] - 63s 180ms/step - loss: 4.1384e-04 - val_loss: 4.4791e-04
# Epoch 22/1024
# 351/351 [==============================] - ETA: 0s - loss: 4.7821e-04
# Epoch 00022: val_loss did not improve from 0.00040
# 351/351 [==============================] - 63s 180ms/step - loss: 4.7821e-04 - val_loss: 4.1934e-04
# Epoch 23/1024
# 351/351 [==============================] - ETA: 0s - loss: 4.1494e-04
# Epoch 00023: val_loss did not improve from 0.00040
# 351/351 [==============================] - 63s 180ms/step - loss: 4.1494e-04 - val_loss: 4.0485e-04
# Epoch 24/1024
# 351/351 [==============================] - ETA: 0s - loss: 4.1706e-04
# Epoch 00024: val_loss improved from 0.00040 to 0.00040, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 63s 180ms/step - loss: 4.1706e-04 - val_loss: 3.9617e-04
# Epoch 25/1024
# 351/351 [==============================] - ETA: 0s - loss: 4.0685e-04
# Epoch 00025: val_loss improved from 0.00040 to 0.00039, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 63s 180ms/step - loss: 4.0685e-04 - val_loss: 3.9058e-04
# Epoch 26/1024
# 351/351 [==============================] - ETA: 0s - loss: 4.0114e-04
# Epoch 00026: val_loss improved from 0.00039 to 0.00039, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 63s 180ms/step - loss: 4.0114e-04 - val_loss: 3.8638e-04
# Epoch 27/1024
# 351/351 [==============================] - ETA: 0s - loss: 4.0031e-04
# Epoch 00027: val_loss did not improve from 0.00039
# 351/351 [==============================] - 63s 180ms/step - loss: 4.0031e-04 - val_loss: 3.9966e-04
# Epoch 28/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.8981e-04
# Epoch 00028: val_loss improved from 0.00039 to 0.00038, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 63s 180ms/step - loss: 3.8981e-04 - val_loss: 3.7809e-04
# Epoch 29/1024
# 351/351 [==============================] - ETA: 0s - loss: 4.1234e-04
# Epoch 00029: val_loss did not improve from 0.00038
# 351/351 [==============================] - 63s 180ms/step - loss: 4.1234e-04 - val_loss: 3.9447e-04
# Epoch 30/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.8494e-04
# Epoch 00030: val_loss did not improve from 0.00038
# 351/351 [==============================] - 63s 180ms/step - loss: 3.8494e-04 - val_loss: 3.8872e-04
# Epoch 31/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.8939e-04
# Epoch 00031: val_loss improved from 0.00038 to 0.00038, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 63s 180ms/step - loss: 3.8939e-04 - val_loss: 3.7678e-04
# Epoch 32/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.8503e-04
# Epoch 00032: val_loss did not improve from 0.00038
# 351/351 [==============================] - 58s 165ms/step - loss: 3.8503e-04 - val_loss: 3.9541e-04
# Epoch 33/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.7868e-04
# Epoch 00033: val_loss improved from 0.00038 to 0.00037, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 58s 165ms/step - loss: 3.7868e-04 - val_loss: 3.6866e-04
# Epoch 34/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.7886e-04
# Epoch 00034: val_loss did not improve from 0.00037
# 351/351 [==============================] - 58s 165ms/step - loss: 3.7886e-04 - val_loss: 3.9477e-04
# Epoch 35/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.7459e-04
# Epoch 00035: val_loss did not improve from 0.00037
# 351/351 [==============================] - 58s 165ms/step - loss: 3.7459e-04 - val_loss: 3.8804e-04
# Epoch 36/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.7245e-04
# Epoch 00036: val_loss did not improve from 0.00037
# 351/351 [==============================] - 58s 165ms/step - loss: 3.7245e-04 - val_loss: 3.7865e-04
# Epoch 37/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.6803e-04
# Epoch 00037: val_loss improved from 0.00037 to 0.00036, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 58s 165ms/step - loss: 3.6803e-04 - val_loss: 3.5895e-04
# Epoch 38/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.6635e-04
# Epoch 00038: val_loss improved from 0.00036 to 0.00035, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 58s 165ms/step - loss: 3.6635e-04 - val_loss: 3.5475e-04
# Epoch 39/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.6538e-04
# Epoch 00039: val_loss improved from 0.00035 to 0.00035, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 58s 165ms/step - loss: 3.6538e-04 - val_loss: 3.5261e-04
# Epoch 40/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.6034e-04
# Epoch 00040: val_loss improved from 0.00035 to 0.00035, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 58s 165ms/step - loss: 3.6034e-04 - val_loss: 3.5237e-04
# Epoch 41/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.6122e-04
# Epoch 00041: val_loss improved from 0.00035 to 0.00035, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 58s 165ms/step - loss: 3.6122e-04 - val_loss: 3.5188e-04
# Epoch 42/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.5945e-04
# Epoch 00042: val_loss did not improve from 0.00035
# 351/351 [==============================] - 58s 165ms/step - loss: 3.5945e-04 - val_loss: 3.7321e-04
# Epoch 43/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.5730e-04
# Epoch 00043: val_loss improved from 0.00035 to 0.00035, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 58s 165ms/step - loss: 3.5730e-04 - val_loss: 3.4989e-04
# Epoch 44/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.5507e-04
# Epoch 00044: val_loss did not improve from 0.00035
# 351/351 [==============================] - 58s 165ms/step - loss: 3.5507e-04 - val_loss: 3.6332e-04
# Epoch 45/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.5728e-04
# Epoch 00045: val_loss improved from 0.00035 to 0.00035, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 58s 165ms/step - loss: 3.5728e-04 - val_loss: 3.4561e-04
# Epoch 46/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.5003e-04
# Epoch 00046: val_loss did not improve from 0.00035
# 351/351 [==============================] - 58s 165ms/step - loss: 3.5003e-04 - val_loss: 3.5234e-04
# Epoch 47/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.5140e-04
# Epoch 00047: val_loss did not improve from 0.00035
# 351/351 [==============================] - 58s 165ms/step - loss: 3.5140e-04 - val_loss: 3.5059e-04
# Epoch 48/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.6923e-04
# Epoch 00048: val_loss improved from 0.00035 to 0.00035, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 58s 165ms/step - loss: 3.6923e-04 - val_loss: 3.4508e-04
# Epoch 49/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.4677e-04
# Epoch 00049: val_loss did not improve from 0.00035
# 351/351 [==============================] - 58s 165ms/step - loss: 3.4677e-04 - val_loss: 3.5187e-04
# Epoch 50/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.4567e-04
# Epoch 00050: val_loss improved from 0.00035 to 0.00034, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 58s 165ms/step - loss: 3.4567e-04 - val_loss: 3.4088e-04
# Epoch 51/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.5052e-04
# Epoch 00051: val_loss did not improve from 0.00034
# 351/351 [==============================] - 58s 165ms/step - loss: 3.5052e-04 - val_loss: 3.5031e-04
# Epoch 52/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.4338e-04
# Epoch 00052: val_loss improved from 0.00034 to 0.00034, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 58s 165ms/step - loss: 3.4338e-04 - val_loss: 3.3555e-04
# Epoch 53/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.4893e-04
# Epoch 00053: val_loss did not improve from 0.00034
# 351/351 [==============================] - 58s 165ms/step - loss: 3.4893e-04 - val_loss: 3.3723e-04
# Epoch 54/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.3902e-04
# Epoch 00054: val_loss did not improve from 0.00034
# 351/351 [==============================] - 58s 165ms/step - loss: 3.3902e-04 - val_loss: 3.4084e-04
# Epoch 55/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.4218e-04
# Epoch 00055: val_loss did not improve from 0.00034
# 351/351 [==============================] - 58s 165ms/step - loss: 3.4218e-04 - val_loss: 3.3698e-04
# Epoch 56/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.3917e-04
# Epoch 00056: val_loss improved from 0.00034 to 0.00033, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 58s 165ms/step - loss: 3.3917e-04 - val_loss: 3.3219e-04
# Epoch 57/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.4018e-04
# Epoch 00057: val_loss did not improve from 0.00033
# 351/351 [==============================] - 58s 165ms/step - loss: 3.4018e-04 - val_loss: 3.4939e-04
# Epoch 58/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.3796e-04
# Epoch 00058: val_loss improved from 0.00033 to 0.00033, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 58s 165ms/step - loss: 3.3796e-04 - val_loss: 3.2760e-04
# Epoch 59/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.3685e-04
# Epoch 00059: val_loss improved from 0.00033 to 0.00033, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 58s 165ms/step - loss: 3.3685e-04 - val_loss: 3.2759e-04
# Epoch 60/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.8662e-04
# Epoch 00060: val_loss did not improve from 0.00033
# 351/351 [==============================] - 58s 165ms/step - loss: 3.8662e-04 - val_loss: 3.6675e-04
# Epoch 61/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.4303e-04
# Epoch 00061: val_loss did not improve from 0.00033
# 351/351 [==============================] - 58s 165ms/step - loss: 3.4303e-04 - val_loss: 3.4490e-04
# Epoch 62/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.4441e-04
# Epoch 00062: val_loss did not improve from 0.00033
# 351/351 [==============================] - 58s 165ms/step - loss: 3.4441e-04 - val_loss: 3.3839e-04
# Epoch 63/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.3799e-04
# Epoch 00063: val_loss did not improve from 0.00033
# 351/351 [==============================] - 58s 165ms/step - loss: 3.3799e-04 - val_loss: 3.6317e-04
# Epoch 64/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.4416e-04
# Epoch 00064: val_loss did not improve from 0.00033
# 351/351 [==============================] - 58s 165ms/step - loss: 3.4416e-04 - val_loss: 4.1244e-04
# Epoch 65/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.3769e-04
# Epoch 00065: val_loss did not improve from 0.00033
# 351/351 [==============================] - 58s 165ms/step - loss: 3.3769e-04 - val_loss: 3.3874e-04
# Epoch 66/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.3330e-04
# Epoch 00066: val_loss improved from 0.00033 to 0.00033, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 58s 165ms/step - loss: 3.3330e-04 - val_loss: 3.2705e-04
# Epoch 67/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.3427e-04
# Epoch 00067: val_loss did not improve from 0.00033
# 351/351 [==============================] - 58s 165ms/step - loss: 3.3427e-04 - val_loss: 3.5678e-04
# Epoch 68/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.3421e-04
# Epoch 00068: val_loss did not improve from 0.00033
# 351/351 [==============================] - 58s 165ms/step - loss: 3.3421e-04 - val_loss: 3.3043e-04
# Epoch 69/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.3282e-04
# Epoch 00069: val_loss improved from 0.00033 to 0.00032, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 58s 165ms/step - loss: 3.3282e-04 - val_loss: 3.2443e-04
# Epoch 70/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.3189e-04
# Epoch 00070: val_loss did not improve from 0.00032
# 351/351 [==============================] - 58s 165ms/step - loss: 3.3189e-04 - val_loss: 3.3347e-04
# Epoch 71/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.2960e-04
# Epoch 00071: val_loss did not improve from 0.00032
# 351/351 [==============================] - 58s 165ms/step - loss: 3.2960e-04 - val_loss: 3.2573e-04
# Epoch 72/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.2982e-04
# Epoch 00072: val_loss improved from 0.00032 to 0.00032, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 58s 165ms/step - loss: 3.2982e-04 - val_loss: 3.2236e-04
# Epoch 73/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.3048e-04
# Epoch 00073: val_loss did not improve from 0.00032
# 351/351 [==============================] - 58s 165ms/step - loss: 3.3048e-04 - val_loss: 4.9870e-04
# Epoch 74/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.3138e-04
# Epoch 00074: val_loss improved from 0.00032 to 0.00032, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 58s 165ms/step - loss: 3.3138e-04 - val_loss: 3.2095e-04
# Epoch 75/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.2508e-04
# Epoch 00075: val_loss did not improve from 0.00032
# 351/351 [==============================] - 58s 165ms/step - loss: 3.2508e-04 - val_loss: 3.2181e-04
# Epoch 76/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.2671e-04
# Epoch 00076: val_loss did not improve from 0.00032
# 351/351 [==============================] - 58s 165ms/step - loss: 3.2671e-04 - val_loss: 3.4749e-04
# Epoch 77/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.2649e-04
# Epoch 00077: val_loss improved from 0.00032 to 0.00032, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 58s 165ms/step - loss: 3.2649e-04 - val_loss: 3.1869e-04
# Epoch 78/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.2600e-04
# Epoch 00078: val_loss improved from 0.00032 to 0.00032, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 58s 165ms/step - loss: 3.2600e-04 - val_loss: 3.1648e-04
# Epoch 79/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.2323e-04
# Epoch 00079: val_loss improved from 0.00032 to 0.00032, saving model to Fish-Gray2.hdf5
# 351/351 [==============================] - 58s 165ms/step - loss: 3.2323e-04 - val_loss: 3.1628e-04
# Epoch 80/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.2073e-04
# Epoch 00080: val_loss did not improve from 0.00032
# 351/351 [==============================] - 58s 165ms/step - loss: 3.2073e-04 - val_loss: 3.4545e-04
# Epoch 81/1024
# 351/351 [==============================] - ETA: 0s - loss: 4.0811e-04
# Epoch 00081: val_loss did not improve from 0.00032
# 351/351 [==============================] - 58s 165ms/step - loss: 4.0811e-04 - val_loss: 3.4285e-04
# Epoch 82/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.3435e-04
# Epoch 00082: val_loss did not improve from 0.00032
# 351/351 [==============================] - 58s 165ms/step - loss: 3.3435e-04 - val_loss: 3.2979e-04
# Epoch 83/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.3293e-04
# Epoch 00083: val_loss did not improve from 0.00032
# 351/351 [==============================] - 58s 165ms/step - loss: 3.3293e-04 - val_loss: 3.3041e-04
# Epoch 84/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.3946e-04
# Epoch 00084: val_loss did not improve from 0.00032
# 351/351 [==============================] - 58s 165ms/step - loss: 3.3946e-04 - val_loss: 3.2494e-04
# Epoch 85/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.2978e-04
# Epoch 00085: val_loss did not improve from 0.00032
# 351/351 [==============================] - 58s 165ms/step - loss: 3.2978e-04 - val_loss: 3.2444e-04
# Epoch 86/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.3429e-04
# Epoch 00086: val_loss did not improve from 0.00032
# 351/351 [==============================] - 58s 165ms/step - loss: 3.3429e-04 - val_loss: 3.2675e-04
# Epoch 87/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.2783e-04
# Epoch 00087: val_loss did not improve from 0.00032
# 351/351 [==============================] - 58s 165ms/step - loss: 3.2783e-04 - val_loss: 3.2832e-04
# Epoch 88/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.2659e-04
# Epoch 00088: val_loss did not improve from 0.00032
# 351/351 [==============================] - 58s 165ms/step - loss: 3.2659e-04 - val_loss: 3.2114e-04
# Epoch 89/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.2740e-04
# Epoch 00089: val_loss did not improve from 0.00032
# 351/351 [==============================] - 58s 165ms/step - loss: 3.2740e-04 - val_loss: 3.2065e-04
# Epoch 90/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.2388e-04
# Epoch 00090: val_loss did not improve from 0.00032
# 351/351 [==============================] - 58s 165ms/step - loss: 3.2388e-04 - val_loss: 3.2857e-04
# Epoch 91/1024
# 351/351 [==============================] - ETA: 0s - loss: 3.2403e-04
# Epoch 00091: val_loss did not improve from 0.00032
# 351/351 [==============================] - 58s 165ms/step - loss: 3.2403e-04 - val_loss: 3.1897e-04

# %% [markdown]
# <h3>模型訓練績效</h3>

# %%
best_iteration = numpy.argmin(score.history['val_loss']) + 1

val_scores = score.history['val_loss'][0:best_iteration]
train_scores = score.history['loss'][0:best_iteration]

fig, ax = plt.subplots(dpi=120)

ax.plot(val_scores, label='val_loss')
ax.plot(train_scores, label='train_loss')

plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# <h3>隨機顯示抽象圖與假圖</h3>

# %%
faint_image_files = glob('%s/F*.jpg' % 'images/faint')

# %%
my_faint_images = []

for image_file in faint_image_files[:24]:
    _image_file = image_file.replace('\\', '/')

    _fish_image = read_image_file(_image_file)

    my_faint_images.append(numpy.reshape(_fish_image, max_dim))

my_faint_images = numpy.array(my_faint_images)

# %%
my_faint_images = my_faint_images.astype('float32') / 255.
my_faint_images = numpy.reshape(my_faint_images, (my_faint_images.shape[0],) + max_dim)

# %%
my_faint_images.shape
# Out:
# (24, 256, 256, 1)

# %% [markdown]
# <h3>產生假圖</h3>

# %%
encoder = Model(inputs=autoencoder.input, outputs=autoencoder.get_layer("encoded").output)

encoded_imgs = encoder.predict(my_faint_images)
encoded_imgs = encoded_imgs.reshape((len(encoded_imgs), 256, 256, 1))

# %%
decoded_imgs = autoencoder.predict(my_faint_images)

# %% [markdown]
# <h3>顯示原圖與假圖</h3>

# %%
def find_faint_file_pos(my_image_id=None):
    pos = -1
    
    if my_image_id is None:
        pos = numpy.random.randint(0, my_faint_images.shape[0], 1)[0]
    else:
        for j in range(len(faint_image_files)):
            image_file = faint_image_files[j]
            if my_image_id in image_file:
                pos = j
                break
            
    if pos == -1:
        pos = numpy.random.randint(0, my_faint_images.shape[0], 1)[0]
        
    return pos

# %%
i = find_faint_file_pos()

# %%
fig, (ax0, ax1, ax2) = plt.subplots(dpi=240, ncols=3)

ax0.imshow(my_faint_images[i].reshape(max_dim[0], max_dim[1]), cmap=plt.cm.binary)
ax0.get_xaxis().set_visible(False)
ax0.get_yaxis().set_visible(False)

ax1.imshow(decoded_imgs[i].reshape(max_dim[0], max_dim[1]), cmap=plt.cm.binary)
ax1.get_xaxis().set_visible(False)
ax1.get_yaxis().set_visible(False)

ax2.imshow(encoded_imgs[i].reshape(max_dim[0], max_dim[1]), cmap=plt.cm.binary)
ax2.get_xaxis().set_visible(False)
ax2.get_yaxis().set_visible(False)

plt.tight_layout()
plt.show()
