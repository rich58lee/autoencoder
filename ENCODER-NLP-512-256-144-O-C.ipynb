# %% [markdown]
# <h3>輸入原影像，經過壓縮轉換，再由轉換壓縮碼，還原成類原圖</h3>

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# %%
from glob import glob
import numpy

# %%
import cv2

# %%
import tensorflow

# %%
import keras

from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator

from keras import layers
from keras.models import Model
from keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from pylab import rcParams
from matplotlib import cm

# %% [markdown]
# <h3>環境設置</h3>

# %%
image_path = 'images/objects/train'
max_dim = (256, 256, 3)
enhance_flag = True

kernel = numpy.array([[-1, -1, -1], [-1, 11, -1], [-1, -1, -1]])

alpha = 0.6 # Contrast control (1.0-3.0)
beta = 2 # Brightness control (0-100)

# %% [markdown]
# <h3>載入魚影像檔</h3>

# %%
def read_image_file(my_image_file, enhanced=False):
    global max_dim, kernel, alpha, beta
    
    _fish_image = cv2.imread(my_image_file, cv2.COLOR_BGR2RGB)
    
    if enhanced:
        _fish_image = cv2.filter2D(_fish_image, -1, kernel)
        _fish_image = cv2.convertScaleAbs(_fish_image.copy(), alpha=alpha, beta=beta)

    _fish_image = cv2.resize(_fish_image.copy(), max_dim[:2])
    
    return _fish_image

# %%
def show_image(my_image):
    fig, ax = plt.subplots(dpi=120)
    ax.imshow(my_image)
    ax.axis('off')
    plt.show()

# %% [markdown]
# <h3>載入魚影像檔</h3>

# %%
datagen = ImageDataGenerator(rotation_range=45,
                             width_shift_range=[0.1, 0.2],
                             height_shift_range=[0.1, 0.2],
                             horizontal_flip=True)

_fish_image = read_image_file('%s/F000079-00001.jpg' % image_path, enhance_flag)

fig, ax = plt.subplots(dpi=120, ncols=3)

ax[0].imshow(_fish_image)
ax[0].axis('off')

_fish_img_data = img_to_array(_fish_image)    
_fish_img_data = numpy.expand_dims(_fish_img_data, 0)

it = datagen.flow(_fish_img_data, batch_size=1)

for i in range(1, 3):
    _batch = it.next()
    _generated_image = _batch[0].astype('uint8')
            
    ax[i].imshow(_generated_image, cmap='gray', interpolation='bicubic')
    ax[i].axis('off')
    
plt.tight_layout()
plt.show()

# %%
def load_data(image_path, train_ratio=0.8, enhanced=False):
    global max_dim

    datagen = ImageDataGenerator(rotation_range=45,
                                 width_shift_range=[0.1, 0.2],
                                 height_shift_range=[0.1, 0.2],
                                 horizontal_flip=True
    )
    
    image_files = glob('%s/F*.jpg' % image_path)

    my_images = []

    for image_file in image_files:
        _image_file = image_file.replace('\\', '/')
        
        _fish_image = read_image_file(_image_file, enhanced)
        
        my_images.append(numpy.reshape(_fish_image, max_dim))

        _fish_img_data = img_to_array(_fish_image)    
        _fish_img_data = numpy.expand_dims(_fish_img_data, 0)
        
        it = datagen.flow(_fish_img_data, batch_size=1)

        for i in range(10):
            _batch = it.next()
            _generated_image = _batch[0].astype('uint8')
            
            my_images.append(numpy.reshape(_generated_image, max_dim))

    my_images = numpy.array(my_images)
    numpy.random.shuffle(my_images)
    
    pos = int(my_images.shape[0] * train_ratio)
    return my_images[:pos], my_images[pos:]

# %%
x_train, x_test = load_data(image_path='images/objects/train', train_ratio=0.8, enhanced=enhance_flag)

# %%
x_train.shape, x_test.shape
# Out:
# ((4488, 256, 256, 3), (1122, 256, 256, 3))

# %% [markdown]
# <h3>將 0 ~ 255 值域，轉換為: 0 ~ 1</h3>

# %%
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# %% [markdown]
# <h3>轉換 256x256 二維度為 65536 一維度</h3>

# %%
x_train = x_train.reshape((x_train.shape[0], numpy.prod(x_train.shape[1:])))
x_test = x_test.reshape((x_test.shape[0], numpy.prod(x_test.shape[1:])))

# %%
x_train.shape, x_test.shape
# Out:
# ((4488, 196608), (1122, 196608))

# %% [markdown]
# <h3>參數設置</h3>
# <p>$$壓縮率: \frac {65536}{64} = 1024$$</p>

# %%
encode_dimension = 12
encoding_dim = encode_dimension * encode_dimension

num_of_epoch = 512
num_of_batch_size = 8

# %% [markdown]
# <h3>建立模型</h3>

# %%
input_img = keras.Input(shape=(x_train.shape[1],), name='input')

# %%
encoded_512 = layers.Dense(512, name='encoded_512', activation='relu')(input_img)
encoded_256 = layers.Dense(256, name='encoded_256', activation='relu')(encoded_512)
encoded = layers.Dense(encoding_dim, name='latent', activation='relu')(encoded_256)

# %%
decoded_256 = layers.Dense(256, name='decoded_256', activation='relu')(encoded)
decoded_512 = layers.Dense(512, name='decoded_512', activation='relu')(decoded_256)
decoded = layers.Dense(x_train.shape[1], name='output', activation='sigmoid')(decoded_512)

# %%
autoencoder = keras.Model(input_img, decoded, name='autoencoder')

# %%
autoencoder.summary()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 196608)]          0
# _________________________________________________________________
# encoded_512 (Dense)          (None, 512)               100663808
# _________________________________________________________________
# encoded_256 (Dense)          (None, 256)               131328
# _________________________________________________________________
# latent (Dense)               (None, 144)               37008
# _________________________________________________________________
# decoded_256 (Dense)          (None, 256)               37120
# _________________________________________________________________
# decoded_512 (Dense)          (None, 512)               131584
# _________________________________________________________________
# output (Dense)               (None, 196608)            100859904
# =================================================================
# Total params: 201,860,752
# Trainable params: 201,860,752
# Non-trainable params: 0
# _________________________________________________________________

# %%
encoder = keras.Model(input_img, encoded)
encoded_input = keras.Input(shape=(encoding_dim,))

# %%
decoder_layer_256 = autoencoder.layers[-3]
decoder_layer_512 = autoencoder.layers[-2]
decoder_layer = autoencoder.layers[-1]

decoder = keras.Model(encoded_input, 
                      decoder_layer(decoder_layer_512(
                          decoder_layer_256(encoded_input))))

# %%
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %% [markdown]
# <h3>訓練模型</h3>

# %%
checkpointer = ModelCheckpoint(
    filepath='NLP-C-0-512-256-144.hdf5', 
    monitor="val_loss", verbose=1, 
    save_best_only=True, mode='auto'
)

earlyStop = EarlyStopping(monitor='val_loss', patience=50)

# %%
score = autoencoder.fit(x_train, x_train,
                        epochs=num_of_epoch,
                        batch_size=num_of_batch_size,
                        shuffle=True,
                        validation_data=(x_test, x_test),
                        callbacks=[checkpointer, earlyStop]
                       )
# Out:
# Epoch 1/512
#   1/561 [..............................] - ETA: 0s - loss: 0.6932WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0034s vs `on_train_batch_end` time: 0.0204s). Check your callbacks.
# 561/561 [==============================] - ETA: 0s - loss: 0.4187
# Epoch 00001: val_loss improved from inf to 0.40003, saving model to NLP-C-0-512-256-144.hdf5
# 561/561 [==============================] - 30s 54ms/step - loss: 0.4187 - val_loss: 0.4000
# Epoch 2/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3956
# Epoch 00002: val_loss improved from 0.40003 to 0.39243, saving model to NLP-C-0-512-256-144.hdf5
# 561/561 [==============================] - 30s 54ms/step - loss: 0.3955 - val_loss: 0.3924
# Epoch 3/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3897
# Epoch 00003: val_loss improved from 0.39243 to 0.38872, saving model to NLP-C-0-512-256-144.hdf5
# 561/561 [==============================] - 30s 53ms/step - loss: 0.3895 - val_loss: 0.3887
# Epoch 4/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3870
# Epoch 00004: val_loss improved from 0.38872 to 0.38682, saving model to NLP-C-0-512-256-144.hdf5
# 561/561 [==============================] - 31s 56ms/step - loss: 0.3870 - val_loss: 0.3868
# Epoch 5/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3852
# Epoch 00005: val_loss improved from 0.38682 to 0.38425, saving model to NLP-C-0-512-256-144.hdf5
# 561/561 [==============================] - 30s 53ms/step - loss: 0.3852 - val_loss: 0.3843
# Epoch 6/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3829
# Epoch 00006: val_loss improved from 0.38425 to 0.38399, saving model to NLP-C-0-512-256-144.hdf5
# 561/561 [==============================] - 31s 55ms/step - loss: 0.3829 - val_loss: 0.3840
# Epoch 7/512
# 560/561 [============================>.] - ETA: 0s - loss: 0.3823
# Epoch 00007: val_loss improved from 0.38399 to 0.38189, saving model to NLP-C-0-512-256-144.hdf5
# 561/561 [==============================] - 30s 53ms/step - loss: 0.3822 - val_loss: 0.3819
# Epoch 8/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3804
# Epoch 00008: val_loss improved from 0.38189 to 0.38118, saving model to NLP-C-0-512-256-144.hdf5
# 561/561 [==============================] - 30s 54ms/step - loss: 0.3805 - val_loss: 0.3812
# Epoch 9/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3796
# Epoch 00009: val_loss improved from 0.38118 to 0.38091, saving model to NLP-C-0-512-256-144.hdf5
# 561/561 [==============================] - 29s 52ms/step - loss: 0.3797 - val_loss: 0.3809
# Epoch 10/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3788
# Epoch 00010: val_loss improved from 0.38091 to 0.38033, saving model to NLP-C-0-512-256-144.hdf5
# 561/561 [==============================] - 30s 54ms/step - loss: 0.3788 - val_loss: 0.3803
# Epoch 11/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3785
# Epoch 00011: val_loss improved from 0.38033 to 0.37927, saving model to NLP-C-0-512-256-144.hdf5
# 561/561 [==============================] - 29s 52ms/step - loss: 0.3785 - val_loss: 0.3793
# Epoch 12/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3784
# Epoch 00012: val_loss improved from 0.37927 to 0.37861, saving model to NLP-C-0-512-256-144.hdf5
# 561/561 [==============================] - 31s 56ms/step - loss: 0.3784 - val_loss: 0.3786
# Epoch 13/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3769
# Epoch 00013: val_loss did not improve from 0.37861
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3769 - val_loss: 0.3788
# Epoch 14/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3766
# Epoch 00014: val_loss did not improve from 0.37861
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3766 - val_loss: 0.3815
# Epoch 15/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3760
# Epoch 00015: val_loss improved from 0.37861 to 0.37840, saving model to NLP-C-0-512-256-144.hdf5
# 561/561 [==============================] - 30s 53ms/step - loss: 0.3760 - val_loss: 0.3784
# Epoch 16/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3761
# Epoch 00016: val_loss improved from 0.37840 to 0.37735, saving model to NLP-C-0-512-256-144.hdf5
# 561/561 [==============================] - 29s 52ms/step - loss: 0.3762 - val_loss: 0.3774
# Epoch 17/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3758
# Epoch 00017: val_loss improved from 0.37735 to 0.37691, saving model to NLP-C-0-512-256-144.hdf5
# 561/561 [==============================] - 31s 55ms/step - loss: 0.3757 - val_loss: 0.3769
# Epoch 18/512
# 560/561 [============================>.] - ETA: 0s - loss: 0.3751
# Epoch 00018: val_loss did not improve from 0.37691
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3751 - val_loss: 0.3776
# Epoch 19/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3747
# Epoch 00019: val_loss did not improve from 0.37691
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3746 - val_loss: 0.3772
# Epoch 20/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3749
# Epoch 00020: val_loss did not improve from 0.37691
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3749 - val_loss: 0.3770
# Epoch 21/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3742
# Epoch 00021: val_loss improved from 0.37691 to 0.37635, saving model to NLP-C-0-512-256-144.hdf5
# 561/561 [==============================] - 29s 52ms/step - loss: 0.3742 - val_loss: 0.3764
# Epoch 22/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3740
# Epoch 00022: val_loss improved from 0.37635 to 0.37557, saving model to NLP-C-0-512-256-144.hdf5
# 561/561 [==============================] - 30s 53ms/step - loss: 0.3740 - val_loss: 0.3756
# Epoch 23/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3738
# Epoch 00023: val_loss did not improve from 0.37557
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3737 - val_loss: 0.3766
# Epoch 24/512
# 560/561 [============================>.] - ETA: 0s - loss: 0.3734
# Epoch 00024: val_loss did not improve from 0.37557
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3734 - val_loss: 0.3759
# Epoch 25/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3738
# Epoch 00025: val_loss did not improve from 0.37557
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3738 - val_loss: 0.3762
# Epoch 26/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3737
# Epoch 00026: val_loss did not improve from 0.37557
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3736 - val_loss: 0.3782
# Epoch 27/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3736
# Epoch 00027: val_loss did not improve from 0.37557
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3736 - val_loss: 0.3759
# Epoch 28/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3729
# Epoch 00028: val_loss improved from 0.37557 to 0.37509, saving model to NLP-C-0-512-256-144.hdf5
# 561/561 [==============================] - 29s 52ms/step - loss: 0.3729 - val_loss: 0.3751
# Epoch 29/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3725
# Epoch 00029: val_loss did not improve from 0.37509
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3726 - val_loss: 0.3753
# Epoch 30/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3727
# Epoch 00030: val_loss did not improve from 0.37509
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3727 - val_loss: 0.3755
# Epoch 31/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3726
# Epoch 00031: val_loss did not improve from 0.37509
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3725 - val_loss: 0.3759
# Epoch 32/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3729
# Epoch 00032: val_loss did not improve from 0.37509
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3729 - val_loss: 0.3754
# Epoch 33/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3724
# Epoch 00033: val_loss did not improve from 0.37509
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3724 - val_loss: 0.3760
# Epoch 34/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3720
# Epoch 00034: val_loss improved from 0.37509 to 0.37508, saving model to NLP-C-0-512-256-144.hdf5
# 561/561 [==============================] - 30s 53ms/step - loss: 0.3722 - val_loss: 0.3751
# Epoch 35/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3721
# Epoch 00035: val_loss did not improve from 0.37508
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3721 - val_loss: 0.3752
# Epoch 36/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3718
# Epoch 00036: val_loss improved from 0.37508 to 0.37490, saving model to NLP-C-0-512-256-144.hdf5
# 561/561 [==============================] - 29s 52ms/step - loss: 0.3718 - val_loss: 0.3749
# Epoch 37/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3725
# Epoch 00037: val_loss did not improve from 0.37490
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3725 - val_loss: 0.3756
# Epoch 38/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3720
# Epoch 00038: val_loss improved from 0.37490 to 0.37473, saving model to NLP-C-0-512-256-144.hdf5
# 561/561 [==============================] - 29s 52ms/step - loss: 0.3719 - val_loss: 0.3747
# Epoch 39/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3718
# Epoch 00039: val_loss did not improve from 0.37473
# 561/561 [==============================] - 13s 24ms/step - loss: 0.3718 - val_loss: 0.3748
# Epoch 40/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3716
# Epoch 00040: val_loss did not improve from 0.37473
# 561/561 [==============================] - 13s 24ms/step - loss: 0.3716 - val_loss: 0.3751
# Epoch 41/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3717
# Epoch 00041: val_loss did not improve from 0.37473
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3717 - val_loss: 0.3749
# Epoch 42/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3714
# Epoch 00042: val_loss improved from 0.37473 to 0.37464, saving model to NLP-C-0-512-256-144.hdf5
# 561/561 [==============================] - 29s 52ms/step - loss: 0.3714 - val_loss: 0.3746
# Epoch 43/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3716
# Epoch 00043: val_loss did not improve from 0.37464
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3716 - val_loss: 0.3754
# Epoch 44/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3721
# Epoch 00044: val_loss did not improve from 0.37464
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3721 - val_loss: 0.3747
# Epoch 45/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3710
# Epoch 00045: val_loss did not improve from 0.37464
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3710 - val_loss: 0.3752
# Epoch 46/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3713
# Epoch 00046: val_loss did not improve from 0.37464
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3713 - val_loss: 0.3761
# Epoch 47/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3712
# Epoch 00047: val_loss did not improve from 0.37464
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3712 - val_loss: 0.3750
# Epoch 48/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3710
# Epoch 00048: val_loss improved from 0.37464 to 0.37458, saving model to NLP-C-0-512-256-144.hdf5
# 561/561 [==============================] - 29s 52ms/step - loss: 0.3710 - val_loss: 0.3746
# Epoch 49/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3714
# Epoch 00049: val_loss did not improve from 0.37458
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3714 - val_loss: 0.3747
# Epoch 50/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3712
# Epoch 00050: val_loss improved from 0.37458 to 0.37413, saving model to NLP-C-0-512-256-144.hdf5
# 561/561 [==============================] - 29s 52ms/step - loss: 0.3712 - val_loss: 0.3741
# Epoch 51/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3711
# Epoch 00051: val_loss did not improve from 0.37413
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3710 - val_loss: 0.3751
# Epoch 52/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3709
# Epoch 00052: val_loss did not improve from 0.37413
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3709 - val_loss: 0.3751
# Epoch 53/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3710
# Epoch 00053: val_loss did not improve from 0.37413
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3710 - val_loss: 0.3751
# Epoch 54/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3704
# Epoch 00054: val_loss did not improve from 0.37413
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3704 - val_loss: 0.3745
# Epoch 55/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3711
# Epoch 00055: val_loss did not improve from 0.37413
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3711 - val_loss: 0.3745
# Epoch 56/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3708
# Epoch 00056: val_loss did not improve from 0.37413
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3708 - val_loss: 0.3751
# Epoch 57/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3710
# Epoch 00057: val_loss did not improve from 0.37413
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3710 - val_loss: 0.3745
# Epoch 58/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3707
# Epoch 00058: val_loss did not improve from 0.37413
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3705 - val_loss: 0.3743
# Epoch 59/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3705
# Epoch 00059: val_loss did not improve from 0.37413
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3705 - val_loss: 0.3753
# Epoch 60/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3709
# Epoch 00060: val_loss did not improve from 0.37413
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3710 - val_loss: 0.3757
# Epoch 61/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3707
# Epoch 00061: val_loss did not improve from 0.37413
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3707 - val_loss: 0.3758
# Epoch 62/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3708
# Epoch 00062: val_loss did not improve from 0.37413
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3708 - val_loss: 0.3751
# Epoch 63/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3703
# Epoch 00063: val_loss did not improve from 0.37413
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3703 - val_loss: 0.3747
# Epoch 64/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3707
# Epoch 00064: val_loss did not improve from 0.37413
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3707 - val_loss: 0.3750
# Epoch 65/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3710
# Epoch 00065: val_loss did not improve from 0.37413
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3710 - val_loss: 0.3752
# Epoch 66/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3702
# Epoch 00066: val_loss did not improve from 0.37413
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3702 - val_loss: 0.3743
# Epoch 67/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3700
# Epoch 00067: val_loss did not improve from 0.37413
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3700 - val_loss: 0.3749
# Epoch 68/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3707
# Epoch 00068: val_loss did not improve from 0.37413
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3707 - val_loss: 0.3744
# Epoch 69/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3705
# Epoch 00069: val_loss did not improve from 0.37413
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3705 - val_loss: 0.3751
# Epoch 70/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3702
# Epoch 00070: val_loss did not improve from 0.37413
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3702 - val_loss: 0.3745
# Epoch 71/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3701
# Epoch 00071: val_loss did not improve from 0.37413
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3701 - val_loss: 0.3745
# Epoch 72/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3700
# Epoch 00072: val_loss did not improve from 0.37413
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3700 - val_loss: 0.3749
# Epoch 73/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3704
# Epoch 00073: val_loss did not improve from 0.37413
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3702 - val_loss: 0.3753
# Epoch 74/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3701
# Epoch 00074: val_loss did not improve from 0.37413
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3701 - val_loss: 0.3747
# Epoch 75/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3702
# Epoch 00075: val_loss did not improve from 0.37413
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3702 - val_loss: 0.3749
# Epoch 76/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3701
# Epoch 00076: val_loss did not improve from 0.37413
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3701 - val_loss: 0.3748
# Epoch 77/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3695
# Epoch 00077: val_loss improved from 0.37413 to 0.37403, saving model to NLP-C-0-512-256-144.hdf5
# 561/561 [==============================] - 29s 52ms/step - loss: 0.3695 - val_loss: 0.3740
# Epoch 78/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3699
# Epoch 00078: val_loss did not improve from 0.37403
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3700 - val_loss: 0.3755
# Epoch 79/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3704
# Epoch 00079: val_loss did not improve from 0.37403
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3704 - val_loss: 0.3747
# Epoch 80/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3702
# Epoch 00080: val_loss did not improve from 0.37403
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3702 - val_loss: 0.3747
# Epoch 81/512
# 560/561 [============================>.] - ETA: 0s - loss: 0.3702
# Epoch 00081: val_loss did not improve from 0.37403
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3702 - val_loss: 0.3749
# Epoch 82/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3705
# Epoch 00082: val_loss did not improve from 0.37403
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3705 - val_loss: 0.3746
# Epoch 83/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3695
# Epoch 00083: val_loss did not improve from 0.37403
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3695 - val_loss: 0.3745
# Epoch 84/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3704
# Epoch 00084: val_loss did not improve from 0.37403
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3704 - val_loss: 0.3753
# Epoch 85/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3703
# Epoch 00085: val_loss did not improve from 0.37403
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3703 - val_loss: 0.3746
# Epoch 86/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3696
# Epoch 00086: val_loss did not improve from 0.37403
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3696 - val_loss: 0.3758
# Epoch 87/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3697
# Epoch 00087: val_loss did not improve from 0.37403
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3697 - val_loss: 0.3746
# Epoch 88/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3698
# Epoch 00088: val_loss did not improve from 0.37403
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3698 - val_loss: 0.3755
# Epoch 89/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3706
# Epoch 00089: val_loss did not improve from 0.37403
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3707 - val_loss: 0.3747
# Epoch 90/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3711
# Epoch 00090: val_loss did not improve from 0.37403
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3711 - val_loss: 0.3748
# Epoch 91/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3692
# Epoch 00091: val_loss did not improve from 0.37403
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3692 - val_loss: 0.3752
# Epoch 92/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3694
# Epoch 00092: val_loss did not improve from 0.37403
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3694 - val_loss: 0.3748
# Epoch 93/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3697
# Epoch 00093: val_loss did not improve from 0.37403
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3697 - val_loss: 0.3751
# Epoch 94/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3704
# Epoch 00094: val_loss did not improve from 0.37403
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3704 - val_loss: 0.3757
# Epoch 95/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3708
# Epoch 00095: val_loss did not improve from 0.37403
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3708 - val_loss: 0.3760
# Epoch 96/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3694
# Epoch 00096: val_loss did not improve from 0.37403
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3696 - val_loss: 0.3747
# Epoch 97/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3690
# Epoch 00097: val_loss improved from 0.37403 to 0.37398, saving model to NLP-C-0-512-256-144.hdf5
# 561/561 [==============================] - 29s 52ms/step - loss: 0.3691 - val_loss: 0.3740
# Epoch 98/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3694
# Epoch 00098: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3695 - val_loss: 0.3754
# Epoch 99/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3697
# Epoch 00099: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3697 - val_loss: 0.3748
# Epoch 100/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3698
# Epoch 00100: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3698 - val_loss: 0.3756
# Epoch 101/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3696
# Epoch 00101: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3696 - val_loss: 0.3752
# Epoch 102/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3696
# Epoch 00102: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3696 - val_loss: 0.3748
# Epoch 103/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3696
# Epoch 00103: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3698 - val_loss: 0.3747
# Epoch 104/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3700
# Epoch 00104: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3700 - val_loss: 0.3751
# Epoch 105/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3697
# Epoch 00105: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3697 - val_loss: 0.3750
# Epoch 106/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3694
# Epoch 00106: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3694 - val_loss: 0.3753
# Epoch 107/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3694
# Epoch 00107: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3694 - val_loss: 0.3753
# Epoch 108/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3702
# Epoch 00108: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3701 - val_loss: 0.3754
# Epoch 109/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3705
# Epoch 00109: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3705 - val_loss: 0.3771
# Epoch 110/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3702
# Epoch 00110: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3702 - val_loss: 0.3745
# Epoch 111/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3692
# Epoch 00111: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3692 - val_loss: 0.3746
# Epoch 112/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3690
# Epoch 00112: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3690 - val_loss: 0.3747
# Epoch 113/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3693
# Epoch 00113: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3693 - val_loss: 0.3749
# Epoch 114/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3694
# Epoch 00114: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3694 - val_loss: 0.3748
# Epoch 115/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3695
# Epoch 00115: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3696 - val_loss: 0.3746
# Epoch 116/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3692
# Epoch 00116: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3692 - val_loss: 0.3752
# Epoch 117/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3696
# Epoch 00117: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3695 - val_loss: 0.3747
# Epoch 118/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3693
# Epoch 00118: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3693 - val_loss: 0.3753
# Epoch 119/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3695
# Epoch 00119: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3695 - val_loss: 0.3759
# Epoch 120/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3704
# Epoch 00120: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3704 - val_loss: 0.3752
# Epoch 121/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3695
# Epoch 00121: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3695 - val_loss: 0.3748
# Epoch 122/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3687
# Epoch 00122: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3687 - val_loss: 0.3742
# Epoch 123/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3692
# Epoch 00123: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3692 - val_loss: 0.3763
# Epoch 124/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3697
# Epoch 00124: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3697 - val_loss: 0.3745
# Epoch 125/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3687
# Epoch 00125: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3687 - val_loss: 0.3747
# Epoch 126/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3694
# Epoch 00126: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3694 - val_loss: 0.3751
# Epoch 127/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3694
# Epoch 00127: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3694 - val_loss: 0.3742
# Epoch 128/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3688
# Epoch 00128: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3688 - val_loss: 0.3763
# Epoch 129/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3706
# Epoch 00129: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3706 - val_loss: 0.3772
# Epoch 130/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3699
# Epoch 00130: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3699 - val_loss: 0.3750
# Epoch 131/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3687
# Epoch 00131: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3688 - val_loss: 0.3745
# Epoch 132/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3688
# Epoch 00132: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3688 - val_loss: 0.3747
# Epoch 133/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3695
# Epoch 00133: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3696 - val_loss: 0.3757
# Epoch 134/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3704
# Epoch 00134: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3704 - val_loss: 0.3753
# Epoch 135/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3688
# Epoch 00135: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3688 - val_loss: 0.3753
# Epoch 136/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3688
# Epoch 00136: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3688 - val_loss: 0.3748
# Epoch 137/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3703
# Epoch 00137: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3703 - val_loss: 0.3767
# Epoch 138/512
# 559/561 [============================>.] - ETA: 0s - loss: 0.3697
# Epoch 00138: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3697 - val_loss: 0.3746
# Epoch 139/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3688
# Epoch 00139: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3688 - val_loss: 0.3743
# Epoch 140/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3691
# Epoch 00140: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3691 - val_loss: 0.3745
# Epoch 141/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3690
# Epoch 00141: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3690 - val_loss: 0.3746
# Epoch 142/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3691
# Epoch 00142: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3691 - val_loss: 0.3749
# Epoch 143/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3690
# Epoch 00143: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3690 - val_loss: 0.3742
# Epoch 144/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3691
# Epoch 00144: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3691 - val_loss: 0.3753
# Epoch 145/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3699
# Epoch 00145: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3699 - val_loss: 0.3746
# Epoch 146/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3688
# Epoch 00146: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3688 - val_loss: 0.3747
# Epoch 147/512
# 561/561 [==============================] - ETA: 0s - loss: 0.3698
# Epoch 00147: val_loss did not improve from 0.37398
# 561/561 [==============================] - 14s 24ms/step - loss: 0.3698 - val_loss: 0.3756

# %% [markdown]
# <h3>模型訓練績效</h3>

# %%
best_iteration = numpy.argmin(score.history['val_loss']) + 1

val_scores = score.history['val_loss'][0:best_iteration]
train_scores = score.history['loss'][0:best_iteration]

fig, ax = plt.subplots(dpi=120)

ax.plot(val_scores, label='val_loss')
ax.plot(train_scores, label='train_loss')

plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# <h3>產生假圖</h3>

# %%
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

# %%
x_test.shape, encoded_imgs.shape, decoded_imgs.shape
# Out:
# ((1122, 196608), (1122, 144), (1122, 196608))

# %% [markdown]
# <h3>隨機顯示抽象圖與假圖</h3>

# %%
i = numpy.random.randint(0, x_test.shape[0], 1)[0]

# %%
fig, ax = plt.subplots(dpi=120)

ax.imshow(x_test[i].reshape(max_dim))
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

plt.show()

# %%
fig, ax = plt.subplots(dpi=120)

encode_dimension = int(encoding_dim**0.5)
encoded_imgs_min = encoded_imgs[i].min()
encoded_imgs_max = encoded_imgs[i].max()
encoded_imgs_val = (encoded_imgs[i] - encoded_imgs_min) / (encoded_imgs_max - encoded_imgs_min)

ax.imshow(encoded_imgs_val.reshape(encode_dimension, encode_dimension), cmap=plt.cm.binary)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

plt.show()

# %%
fig, ax = plt.subplots(dpi=120)

ax.imshow(decoded_imgs[i].reshape(max_dim), cmap=plt.cm.binary)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

plt.show()

# %%
fig, ax = plt.subplots(dpi=120)

diff_image = x_test[i] - decoded_imgs[i]
diff_image_min = diff_image.min()
diff_image_max = diff_image.max()
diff_image_val = (diff_image - diff_image_min) / (diff_image_max - diff_image_min)

ax.imshow(diff_image_val.reshape(max_dim), cmap=plt.cm.binary)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

plt.show()

# %% [markdown]
# <h3>顯示原圖與假圖</h3>

# %%
fig, (ax0, ax1, ax2, ax3) = plt.subplots(dpi=120, ncols=4)

ax0.imshow(x_test[i].reshape(max_dim), cmap=plt.cm.binary)
ax0.get_xaxis().set_visible(False)
ax0.get_yaxis().set_visible(False)

encoded_imgs_min = encoded_imgs[i].min()
encoded_imgs_max = encoded_imgs[i].max()
encoded_imgs_val = (encoded_imgs[i] - encoded_imgs_min) / (encoded_imgs_max - encoded_imgs_min)

ax1.imshow(encoded_imgs_val.reshape(encode_dimension, encode_dimension), cmap=plt.cm.binary)

ax1.get_xaxis().set_visible(False)
ax1.get_yaxis().set_visible(False)

ax2.imshow(decoded_imgs[i].reshape(max_dim), cmap=plt.cm.binary)
ax2.get_xaxis().set_visible(False)
ax2.get_yaxis().set_visible(False)

diff_image = x_test[i] - decoded_imgs[i]
diff_image_min = diff_image.min()
diff_image_max = diff_image.max()
diff_image_val = (diff_image - diff_image_min) / (diff_image_max - diff_image_min)

ax3.imshow(diff_image_val.reshape(max_dim), cmap=plt.cm.binary)
ax3.get_xaxis().set_visible(False)
ax3.get_yaxis().set_visible(False)

plt.tight_layout()
plt.show()

# %%
def benchmark(my_diff_image):
    diff = 0.0
    
    for i in range(max_dim[2]):
        diff += numpy.sum(numpy.square(diff_image[i]))
        
    return diff**0.5

# %%
benchmark(diff_image.reshape(max_dim))
# Out:
# 0.07300853334972128

# %% [markdown]
# <h3>隨機顯示抽象圖</h3>

# %%
faint_image_files = glob('%s/F*.jpg' % 'images/objects/faint')

my_faint_images = []

for image_file in faint_image_files[:24]:
    _image_file = image_file.replace('\\', '/')

    _fish_image = read_image_file(_image_file, enhance_flag)

    my_faint_images.append(numpy.reshape(_fish_image, max_dim))

my_faint_images = numpy.array(my_faint_images)

my_faint_images = my_faint_images.astype('float32') / 255.

_max_dim = max_dim[0] * max_dim[1] * max_dim[2]
my_faint_images = numpy.reshape(my_faint_images, (my_faint_images.shape[0], _max_dim))

my_faint_images.shape
# Out:
# (24, 196608)

# %%
faint_encoded_imgs = encoder.predict(my_faint_images)
faint_decoded_imgs = decoder.predict(faint_encoded_imgs)

# %%
def find_faint_file_pos(my_image_id=None):
    pos = -1
    
    if my_image_id is None:
        pos = numpy.random.randint(0, my_faint_images.shape[0], 1)[0]
    else:
        for j in range(len(faint_image_files)):
            image_file = faint_image_files[j]
            if my_image_id in image_file:
                pos = j
                break
            
    if pos == -1:
        pos = numpy.random.randint(0, my_faint_images.shape[0], 1)[0]
        
    return pos

# %%
i = find_faint_file_pos()

# %%
fig, ax = plt.subplots(dpi=120)

ax.imshow(my_faint_images[i].reshape(max_dim))
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

plt.show()

# %%
fig, ax = plt.subplots(dpi=120)

faint_encoded_imgs_min = faint_encoded_imgs[i].min()
faint_encoded_imgs_max = faint_encoded_imgs[i].max()
faint_encoded_imgs_val = (faint_encoded_imgs[i] - faint_encoded_imgs_min) / (faint_encoded_imgs_max - faint_encoded_imgs_min)

ax.imshow(faint_encoded_imgs_val.reshape(encode_dimension, encode_dimension), cmap=plt.cm.binary)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

plt.show()

# %%
fig, ax = plt.subplots(dpi=120)

ax.imshow(faint_decoded_imgs[i].reshape(max_dim), cmap=plt.cm.binary)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

plt.show()

# %%
fig, ax = plt.subplots(dpi=120)

faint_diff_image = my_faint_images[i] - faint_decoded_imgs[i]
faint_diff_image_min = faint_diff_image.min()
faint_diff_image_max = faint_diff_image.max()
faint_diff_image_val = (faint_diff_image - faint_diff_image_min) / (faint_diff_image_max - faint_diff_image_min)

ax.imshow(faint_diff_image_val.reshape(max_dim), cmap=plt.cm.binary)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

plt.show()

# %%
benchmark(faint_diff_image.reshape(max_dim))
# Out:
# 0.07300853334972128

# %%
my_model = keras.models.load_model('NLP-C-0-512-256-144.hdf5')
print(my_model.summary())

faint_encoder = Model(inputs=my_model.input, outputs=my_model.get_layer('latent').output)

faint_encoded_imgs = faint_encoder.predict(my_faint_images)
faint_encoded_imgs = faint_encoded_imgs.reshape((len(faint_encoded_imgs), encode_dimension, encode_dimension, 1))

faint_decoded_imgs = my_model.predict(my_faint_images)
# Out:
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 196608)]          0
# _________________________________________________________________
# encoded_512 (Dense)          (None, 512)               100663808
# _________________________________________________________________
# encoded_256 (Dense)          (None, 256)               131328
# _________________________________________________________________
# latent (Dense)               (None, 144)               37008
# _________________________________________________________________
# decoded_256 (Dense)          (None, 256)               37120
# _________________________________________________________________
# decoded_512 (Dense)          (None, 512)               131584
# _________________________________________________________________
# output (Dense)               (None, 196608)            100859904
# =================================================================
# Total params: 201,860,752
# Trainable params: 201,860,752
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# <h3>顯示原圖與假圖</h3>

# %%
fig, (ax0, ax1, ax2, ax3) = plt.subplots(dpi=240, ncols=4)

ax0.imshow(my_faint_images[i].reshape(max_dim))
ax0.get_xaxis().set_visible(False)
ax0.get_yaxis().set_visible(False)

faint_encoded_imgs_min = faint_encoded_imgs[i].min()
faint_encoded_imgs_max = faint_encoded_imgs[i].max()
faint_encoded_imgs_val = (faint_encoded_imgs[i] - faint_encoded_imgs_min) / (faint_encoded_imgs_max - faint_encoded_imgs_min)

ax1.imshow(faint_encoded_imgs_val.reshape(encode_dimension, encode_dimension), cmap=plt.cm.binary)
ax1.get_xaxis().set_visible(False)
ax1.get_yaxis().set_visible(False)

ax2.imshow(faint_decoded_imgs[i].reshape(max_dim))
ax2.get_xaxis().set_visible(False)
ax2.get_yaxis().set_visible(False)

faint_diff_image = my_faint_images[i] - faint_decoded_imgs[i]
faint_diff_image_min = faint_diff_image.min()
faint_diff_image_max = faint_diff_image.max()
faint_diff_image_val = (faint_diff_image - faint_diff_image_min) / (faint_diff_image_max - faint_diff_image_min)

ax3.imshow(faint_diff_image_val.reshape(max_dim), cmap=plt.cm.binary)
ax3.get_xaxis().set_visible(False)
ax3.get_yaxis().set_visible(False)

plt.tight_layout()
plt.show()

# %%
benchmark(faint_diff_image)
# Out:
# 0.07300853334972128

# %% [markdown]
# <h3>重建全圖</h3>

# %%
full_image_files = glob('%s/F*.jpg' % 'images/full')

my_full_images = []

for image_file in full_image_files[:24]:
    _image_file = image_file.replace('\\', '/')

    _fish_image = read_image_file(_image_file, enhance_flag)

    my_full_images.append(numpy.reshape(_fish_image, max_dim))

my_full_images = numpy.array(my_full_images)

my_full_images = my_full_images.astype('float32') / 255.

_max_dim = max_dim[0] * max_dim[1] * max_dim[2]
my_full_images = numpy.reshape(my_full_images, (my_full_images.shape[0], _max_dim))

my_full_images.shape
# Out:
# (24, 196608)

# %%
my_model = keras.models.load_model('NLP-C-0-512-256-144.hdf5')
print(my_model.summary())

# %%
full_encoder = Model(inputs=my_model.input, outputs=my_model.get_layer('latent').output)

full_encoded_imgs = full_encoder.predict(my_full_images)
full_encoded_imgs = full_encoded_imgs.reshape((len(full_encoded_imgs), encode_dimension, encode_dimension, 1))

full_decoded_imgs = my_model.predict(my_full_images)

# %%
def find_full_file_pos(my_image_id=None):
    pos = -1
    
    if my_image_id is None:
        pos = numpy.random.randint(0, my_full_images.shape[0], 1)[0]
    else:
        for j in range(len(full_image_files)):
            image_file = full_image_files[j]
            if my_image_id in image_file:
                pos = j
                break
            
    if pos == -1:
        pos = numpy.random.randint(0, my_full_images.shape[0], 1)[0]
        
    return pos

# %%
i = find_full_file_pos()

# %%
fig, (ax0, ax1, ax2, ax3) = plt.subplots(dpi=240, ncols=4)

ax0.imshow(my_full_images[i].reshape(max_dim))
ax0.get_xaxis().set_visible(False)
ax0.get_yaxis().set_visible(False)

full_encoded_imgs_min = full_encoded_imgs[i].min()
full_encoded_imgs_max = full_encoded_imgs[i].max()
full_encoded_imgs_val = (full_encoded_imgs[i] - full_encoded_imgs_min) / (full_encoded_imgs_max - full_encoded_imgs_min)

ax1.imshow(full_encoded_imgs_val.reshape(encode_dimension, encode_dimension), cmap=plt.cm.binary)
ax1.get_xaxis().set_visible(False)
ax1.get_yaxis().set_visible(False)

ax2.imshow(full_decoded_imgs[i].reshape(max_dim))
ax2.get_xaxis().set_visible(False)
ax2.get_yaxis().set_visible(False)

full_diff_image = my_full_images[i] - full_decoded_imgs[i]
full_diff_image_min = full_diff_image.min()
full_diff_image_max = full_diff_image.max()
full_diff_image_val = (full_diff_image - full_diff_image_min) / (full_diff_image_max - full_diff_image_min)

ax3.imshow(full_diff_image_val.reshape(max_dim), cmap=plt.cm.binary)
ax3.get_xaxis().set_visible(False)
ax3.get_yaxis().set_visible(False)

plt.tight_layout()
plt.show()
